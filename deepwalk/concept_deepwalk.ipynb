# %% [markdown]
# ### 构建Graph

# %%
import json
import numpy as np
import networkx as nx
from sklearn.preprocessing import LabelEncoder

jsonl_file = "/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/en_title_100w_audio_filter_v2.jsonl"

# 读取jsonl文件并提取theme_1和topic的关系
edges = []
themes = set()
topics = set()

with open(jsonl_file, 'r') as f:
    for line in f:
        data = json.loads(line)
        theme_1 = f"theme_{data['theme_1']}"  # 添加前缀 "theme_"
        topic_list = data['topic_map'] 
        
        # 如果 topic 是字符串而非列表，转换为单元素列表
        if isinstance(topic_list, str):
            topic_list = [topic_list]
        # 如果 topic 是列表，一一对应
        for topic in topic_list:
            topic = f"topic_{topic}"  # 添加前缀 "topic_"
            print(f"Processed: theme_1 = {theme_1}, topic = {topic}")
            edges.append((theme_1, topic))
            themes.add(theme_1)
            topics.add(topic)

G = nx.Graph()
G.add_edges_from(edges)

# 为每个节点添加标签
for theme in themes:
    G.nodes[theme]['label'] = 'theme'  # 给 theme 节点添加标签

for topic in topics:
    G.nodes[topic]['label'] = 'topic'  # 给 topic 节点添加标签

# 构建节点特征矩阵和邻接矩阵
nodes = list(G.nodes)
adj_matrix = nx.adjacency_matrix(G, nodelist=nodes).todense()

label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(nodes)
num_classes = len(label_encoder.classes_)
feature_matrix = np.eye(num_classes)[labels]

cites_lines = []
for edge in G.edges():
    cites_line = f"{edge[0]}\t{edge[1]}"
    cites_lines.append(cites_line)

# 保存cora.cites文件
with open("/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/cora_819_alldata.cites", "w") as f:
    for line in cites_lines:
        f.write(line + '\n')

content_lines = []
node_ids = list(G.nodes)
for node_id in node_ids:
    attributes = [1 if G.has_edge(node_id, other_id) or G.has_edge(other_id, node_id) else 0 for other_id in node_ids]
    data = G.nodes[node_id]
    label = data['label']
    content_line = f"{node_id}\t{' '.join(map(str, attributes))}\t{label}"
    content_lines.append(content_line)

# 保存cora.content文件
with open("/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/cora_819_alldata.content", "w") as f:
    for line in content_lines:
        f.write(line + '\n')

print("cora.cites 和 cora.content 文件已保存。")

# %% [markdown]
# ### 检查构建的Graph

# %%
import networkx as nx

# 读取cora.cites文件，构建图
cites_file = "/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/cora_819_alldata.cites"
edges = []

with open(cites_file, 'r') as f:
    for line in f:
        source, target = line.strip().split()
        edges.append((source, target))

# 使用NetworkX创建图
G = nx.Graph()
G.add_edges_from(edges)

# 读取cora.content文件并统计每个节点的度数
content_file = "/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/cora_819_alldata.content"
node_degrees = {}

with open(content_file, 'r') as f:
    for line in f:
        node_id = line.strip().split()[0]  # 获取节点ID
        node_degrees[node_id] = G.degree[node_id] if node_id in G else 0  # 获取度数，如果节点不在图中则为0

# 打印每个节点的度数
for node_id, degree in node_degrees.items():
    print(f"节点 {node_id} 有 {degree} 条边")
# 打印图中总的边数
total_edges = G.number_of_edges()
print(f"图中一共有 {total_edges} 条边")

# %% [markdown]
# ### Deepwalk生成嵌入

# %%
import torch
import numpy as np
import os
import random
import pandas as pd
import scipy.sparse as sp
from torch_geometric.data import Data
from sklearn.preprocessing import LabelEncoder
import networkx as nx
from gensim.models import Word2Vec
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from joblib import Parallel, delayed
from tqdm import tqdm 
import toml
with open('config.toml', 'r') as f:
    config = toml.load(f)
version = "v2"

data_path = config[f'data_path_{version}']
content_data = config[f'content_{version}']
cites_data = config[f'cites_{version}']
model_save_path = config['model_save_path']
png_path = config['png_path']
walks_save_path = config['walks_save_path']
dimensions = int(config['dimensions'])
theme_emb_path = config['theme_emb_path']
topic_emb_path = config['topic_emb_path']


def seed_everything(seed=2023):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

seed_everything()

def load_cora_data(data_path=data_path):
    content_df = pd.read_csv(os.path.join(data_path, content_data), delimiter="\t", header=None)
    content_df.set_index(0, inplace=True)
    print(content_df.shape) 
    index = content_df.index.tolist()

    features = np.array([list(map(float, row[0].split())) for row in content_df.iloc[:, :-1].values])
    features = sp.csr_matrix(features, dtype=np.float32)

    labels = content_df.values[:, -1]
    print(len(labels))
    class_encoder = LabelEncoder()
    labels = class_encoder.fit_transform(labels)

    cites_df = pd.read_csv(os.path.join(data_path, cites_data), delimiter="\t", header=None)
    cites_df[0] = cites_df[0].astype(str)
    cites_df[1] = cites_df[1].astype(str)
    cites = [tuple(x) for x in cites_df.values]
    edges = [(index.index(cite[0]), index.index(cite[1])) for cite in cites]
    edges = np.array(edges).T
    
    data = Data(x=torch.from_numpy(np.array(features.todense())),
                edge_index=torch.LongTensor(edges),
                y=torch.from_numpy(labels))
    if version == "v1":
        idx_train = range(400)
        idx_val = range(400, 500)
        idx_test = range(500, 539)
    elif version == "v2":
        idx_train = range(242)
        idx_val = range(242)
        idx_test = range(242)

    def index_to_mask(index, size):
        mask = np.zeros(size, dtype=bool)
        mask[index] = True
        return mask

    data.train_mask = index_to_mask(idx_train, size=labels.shape[0])
    data.val_mask = index_to_mask(idx_val, size=labels.shape[0])
    data.test_mask = index_to_mask(idx_test, size=labels.shape[0])

    def to_networkx(data):
        edge_index = data.edge_index.to(torch.device('cpu')).numpy()
        G = nx.Graph()
        for src, tar in edge_index.T:
            G.add_edge(index[src], index[tar])
        return G

    networkx_data = to_networkx(data)
    print(networkx_data)

    return data, networkx_data, index


pyg_data, networkx_data, node_index = load_cora_data()

def deepwalk(graph, num_walks, walk_length, save_path):
    def random_walk(start_node):
        walk = [start_node]
        current_node = start_node
        for _ in range(walk_length - 1):
            neighbors = list(graph.neighbors(current_node))
            if neighbors:
                current_node = random.choice(neighbors)
                walk.append(current_node)
            else:
                break
        return walk

    walks = []
    nodes = list(graph.nodes())
    
    for node in tqdm(nodes, desc="Generating random walks"):
        results = Parallel(n_jobs=-1)(delayed(random_walk)(node) for _ in range(num_walks))
        walks.extend(results)
    
    with open(save_path, 'w') as f:
        for walk in tqdm(walks, desc="Saving random walks"):
            f.write(" ".join(map(str, walk)) + "\n")
    
    return walks


def DeepWalk_run(networkx_data, dimensions=64, walk_length=10, num_walks=50, window_size=10, model_save_path="deepwalk.model", walks_save_path="random_walks.txt"):
    print('walk_length:', walk_length)
    walks = deepwalk(networkx_data, num_walks=num_walks, walk_length=walk_length, save_path=walks_save_path)
    model = Word2Vec(walks, vector_size=int(dimensions), window=window_size, min_count=1, sg=1, workers=4)
    nodes = model.wv.index_to_key
    embeddings = model.wv[nodes]
    
    # 保存模型
    model.save(model_save_path)
    
    return model, nodes, embeddings

def plot_embeddings(embeddings, labels, output_path):
    tsne = TSNE(n_components=2)
    reduced_embeddings = tsne.fit_transform(embeddings)

    plt.figure(figsize=(10, 10))
    scatter = plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], c=labels, cmap="jet", alpha=0.6)
    legend1 = plt.legend(*scatter.legend_elements(), title="Classes")
    plt.gca().add_artist(legend1)
    plt.savefig(output_path)
    plt.close()

def save_embeddings(embeddings, node_index):
    if len(embeddings) != len(node_index):
        raise ValueError("The length of embeddings and node_index must match.")

    embeddings_df = pd.DataFrame(embeddings)
    embeddings_df['index'] = node_index
    # 将 index 列移动到第一列
    embeddings_df = embeddings_df[['index'] + [col for col in embeddings_df.columns if col != 'index']]
    # 分离开头是'theme_'的数据和开头是'topic_'的数据
    theme_df = embeddings_df[embeddings_df['index'].str.startswith('theme_')]
    topic_df = embeddings_df[embeddings_df['index'].str.startswith('topic_')]
    theme_df.to_csv(os.path.join(data_path, theme_emb_path), index=False)
    topic_df.to_csv(os.path.join(data_path, topic_emb_path), index=False)

_, _, deepwalk_embeddings = DeepWalk_run(networkx_data, dimensions=dimensions, walk_length=10, num_walks=200, 
                                        model_save_path=os.path.join(data_path, model_save_path),
                                        walks_save_path=os.path.join(data_path, walks_save_path))
print("DeepWalk_embeddings:", np.array(deepwalk_embeddings).shape)
save_embeddings(deepwalk_embeddings, node_index)


# plot_embeddings(deepwalk_embeddings, pyg_data.y.numpy(), png_path)
# Out:
# (242, 2)
# 242
# Graph with 242 nodes and 3585 edges
# walk_length: 10
# Generating random walks: 100%|██████████| 242/242 [00:48<00:00,  4.99it/s]
# Saving random walks: 100%|██████████| 48400/48400 [00:00<00:00, 478240.10it/s]
# DeepWalk_embeddings: (242, 128)

# %% [markdown]
# ### 分别保存theme和topic的相似度矩阵

# %%
import os
import pandas as pd
import numpy as np
import torch
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
import toml

with open('config.toml', 'r') as f:
    config = toml.load(f)

version = "v2"

data_path = config[f'data_path_{version}']
content_data = config[f'content_{version}']
cites_data = config[f'cites_{version}']
model_save_path = config['model_save_path']
theme_sim_path = config['theme_sim_path']
topic_sim_path = config['topic_sim_path']

class configs():
    def __init__(self):
        self.data_path = data_path
        self.model_path = os.path.join(data_path, model_save_path)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

cfg = configs()

def load_cora_data(data_path=data_path):
    content_df = pd.read_csv(os.path.join(data_path, content_data), delimiter="\t", header=None)
    content_df.set_index(0, inplace=True)
    index = content_df.index.astype(str).tolist()  # 使用字符串索引

    original_content = content_df.iloc[:, -1].tolist()

    return original_content, index

def load_model(model_path):
    model = Word2Vec.load(model_path)
    return model

def find_similar_vectors(model, target_node, node_index, top_k=5):
    if target_node.startswith('topic_'):
        relevant_nodes = [node for node in model.wv.index_to_key if node.startswith('topic_')]
    elif target_node.startswith('theme_'):
        relevant_nodes = [node for node in model.wv.index_to_key if node.startswith('theme_')]
    else:
        raise ValueError(f"Node '{target_node}' does not start with 'topic_' or 'theme_'")
    
    # 获取目标节点的向量
    try:
        target_vector = model.wv[target_node]
    except KeyError:
        raise KeyError(f"Key '{target_node}' not present in the model vocabulary")
    relevant_vectors = np.array([model.wv[node] for node in relevant_nodes])
    similarities = cosine_similarity([target_vector], relevant_vectors)[0]
    
    target_index = relevant_nodes.index(target_node)
    similarities[target_index] = -np.inf
    
    # 找到最相似的 top_k 个节点
    top_k_indices = similarities.argsort()[-top_k:][::-1]
    top_k_similarities = similarities[top_k_indices]
    top_k_nodes = [relevant_nodes[i] for i in top_k_indices]
    
    # print("relevant_nodes:")
    # print(relevant_nodes)
    # print("top_k_nodes:")
    # print(top_k_nodes)
    # 将最相似的节点转换为ID
    top_k_ids = [node_index.index(node) for node in top_k_nodes]

    return top_k_ids, top_k_nodes, top_k_similarities

if __name__ == '__main__':
    original_content, node_index = load_cora_data(cfg.data_path)
    # print("node_index:")
    # print(node_index)
    
    model_path = cfg.model_path
    model = load_model(model_path)

    topic_results = []
    theme_results = []

    for idx, target_node in enumerate(node_index):
        if not target_node.startswith('topic_') and not target_node.startswith('theme_'):
            continue  # 忽略非 topic_ 和 theme_ 开头的节点
        
        top_k_ids, top_k_nodes, top_k_similarities = find_similar_vectors(model, target_node, node_index)
        
        result = {
            'id': idx+1,
            '节点实际内容': target_node,
            '最相似的前5个节点id及相似度': [(top_k_ids[i]+1, top_k_similarities[i]) for i in range(5)]
        }
        for i in range(5):
            result[f'最相似的节点 {i+1}'] = top_k_nodes[i]
        
        if target_node.startswith('topic_'):
            topic_results.append(result)
        elif target_node.startswith('theme_'):
            theme_results.append(result)

    # 将结果保存到 DataFrame 并导出为 Excel 文件
    if topic_results:
        topic_results_df = pd.DataFrame(topic_results)
        topic_output_file_path = os.path.join(data_path, topic_sim_path)
        topic_results_df.to_excel(topic_output_file_path, index=False)
        print(f"Topic results have been saved to {topic_output_file_path}.")

    if theme_results:
        theme_results_df = pd.DataFrame(theme_results)
        theme_output_file_path = os.path.join(data_path, theme_sim_path)
        theme_results_df.to_excel(theme_output_file_path, index=False)
        print(f"Theme results have been saved to {theme_output_file_path}.")
# Out:
# Topic results have been saved to /mnt/new_pfs/liming_team/auroraX/caoying/Graph-Networks/topic_data/v2/topic_sim.xlsx.
# Theme results have been saved to /mnt/new_pfs/liming_team/auroraX/caoying/Graph-Networks/topic_data/v2/theme_sim.xlsx.

# %% [markdown]
# ### 将 theme 按序拼接到 topic_id文件中
# #### grapth中需要theme节点，所以需要将theme节点id添加到topic_id文件中

# %%
import os
import json
import csv
import toml
with open('config.toml', 'r') as f:
    config = toml.load(f)
version = "v2"

data_path = config[f'data_path_{version}']
id4topics = config['id4topics']
topics_themes_id = config['topics_themes_id']
theme_emb_path = config['theme_emb_path']

topic_id_file = os.path.join(data_path, id4topics)
with open(topic_id_file, 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)
# 获取当前最大序号
max_index = max(data.values())

# 读取 theme 文件并提取第一列的名字
theme_emb_file = os.path.join(data_path, theme_emb_path)
names = []
with open(theme_emb_file, 'r', encoding='utf-8') as theme_emb:
    reader = csv.reader(theme_emb)
    names = [row[0] for row in reader if row[0].startswith('theme_')]

# 将提取的名字按顺序拼接到 JSON 对象中
for name in names:
    max_index += 1
    data[name] = max_index

# 将更新后的 JSON 对象写回文件
topics_themes_file = os.path.join(data_path, topics_themes_id)
with open(topics_themes_file, 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, ensure_ascii=False, indent=4)

print("JSON 文件已成功更新并保存为 topics_themes_id.json")
# Out:
# JSON 文件已成功更新并保存为 topics_themes_id.json

# %% [markdown]
# ### 将边文件 cora_819_alldata.cites 中的theme 和 topic转化为id映射

# %%
import os
import json
import csv
import toml

with open('config.toml', 'r') as f:
    config = toml.load(f)
version = "v2"


data_path = config[f'data_path_{version}']
content_data = config[f'content_{version}']
cites_data = config[f'cites_{version}']

# 需要注意的是topics_themes_id中的 id是从 1 开始的，但是 gnn中要求是从 0 开始的，所以cities映射的时候，要将 id-1 处理
# 读取JSON文件并创建名字到ID的映射
with open(topics_themes_file, 'r', encoding='utf-8') as json_file:
    name_to_id = json.load(json_file)
cities_file = os.path.join(data_path, cites_data)
# 读取cities文件并进行名字到ID的映射转换
with open(cities_file, 'r', encoding='utf-8') as cities_file:
    edges = cities_file.readlines()

edges_with_id = []
for edge in edges:
    node1, node2 = edge.strip().split('\t')
    if node1.startswith('topic_') :
        node1 = node1[len('topic_'):]
        
    if node2.startswith('topic_') :
        node2 = node2[len('topic_'):]
    if node1 in name_to_id and node2 in name_to_id:
        node1_id = name_to_id.get(node1) - 1
        node2_id = name_to_id.get(node2) - 1
        edges_with_id.append(f"{node1_id}\t{node2_id}\n")
    else:
        print(f"Warning: One of the nodes '{node1}' or '{node2}' is not found in the JSON mapping.")

# 将转换后的边写入新的文件
cites_id_path = os.getenv('cites_id')
cites_id_file = os.path.join(data_path, cites_id_path)
with open(cites_id_file, 'w', encoding='utf-8') as updated_cities_file:
    updated_cities_file.writelines(edges_with_id)

# %% [markdown]
# ### 将两个embedding文件的topic/theme名字改为id，按id序保存在一个文件中

# %%
# 将两个embedding文件的名字改为id，按序保存
import os
import json
import csv
import pandas as pd
import toml

with open('config.toml', 'r') as f:
    config = toml.load(f)
version = "v2"

data_path = config[f'data_path_{version}']
theme_emb_path = config[f'theme_emb_path']
topic_emb_path = config[f'topic_emb_path']
topics_themes_id = config[f'topics_themes_id']
topics_themes_id_emb = config[f'topics_themes_id_emb']

theme_emb_file = os.path.join(data_path, theme_emb_path)
topic_emb_file = os.path.join(data_path, topic_emb_path)
topics_themes_id_file = os.path.join(data_path, topics_themes_id)
topics_themes_id_emb_file = os.path.join(data_path, topics_themes_id_emb)

# 读取JSON文件
with open(topics_themes_id_file, 'r', encoding='utf-8') as f:
    name_to_id = json.load(f)

theme_emb = pd.read_csv(theme_emb_file,header=0)
topic_emb = pd.read_csv(topic_emb_file,header=0)

theme_emb.iloc[:, 0] = theme_emb.iloc[:, 0].map(name_to_id).apply(lambda x: x - 1 if pd.notna(x) else x)
topic_emb.iloc[:, 0] = topic_emb.iloc[:, 0].str.replace('topic_', '')
topic_emb.iloc[:, 0] = topic_emb.iloc[:, 0].map(name_to_id).apply(lambda x: x - 1 if pd.notna(x) else x)

merged_data = pd.concat([theme_emb, topic_emb])
# 按照 ID 排序
sorted_data = merged_data.sort_values(by=merged_data.columns[0])
# 保存到一个新的文件中
sorted_data.to_csv(topics_themes_id_emb_file, index=False)

# %% [markdown]
# ### 可视化：绘制heatmap

# %%
import os
import pandas as pd
import numpy as np
import torch
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager

class configs():
    def __init__(self):
        self.data_path = r'/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data'
        self.model_path = r'/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/deepwalk819_alldata1.model'
        self.embedding_dim = 128
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.font_path = r'/mnt/new_pfs/liming_team/auroraX/chenlong/testdata/simhei.ttf'  # 字体路径

cfg = configs()

def load_cora_data(data_path='/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data'):
    content_df = pd.read_csv(os.path.join(data_path, "cora_819_alldata.content"), delimiter="\t", header=None)
    content_df.set_index(0, inplace=True)
    index = content_df.index.astype(str).tolist()  # 使用字符串索引

    original_content = content_df.iloc[:, -1].tolist()

    return original_content, index

def load_model(model_path):
    model = Word2Vec.load(model_path)
    return model

def find_similar_vectors(model, target_node, node_index, top_k=5):
    # 获取目标节点的类别（topic_ 或 theme_）
    if target_node.startswith('topic_'):
        relevant_nodes = [node for node in model.wv.index_to_key if node.startswith('topic_')]
    elif target_node.startswith('theme_'):
        relevant_nodes = [node for node in model.wv.index_to_key if node.startswith('theme_')]
    else:
        raise ValueError(f"Node '{target_node}' does not start with 'topic_' or 'theme_'")
    
    # 获取目标节点的向量
    try:
        target_vector = model.wv[target_node]
    except KeyError:
        raise KeyError(f"Key '{target_node}' not present in the model vocabulary")

    # 计算所有相关节点的相似度
    relevant_vectors = np.array([model.wv[node] for node in relevant_nodes])
    similarities = cosine_similarity([target_vector], relevant_vectors)[0]
    
    # 设置自身相似度为负无穷大，确保不会被选中
    target_index = relevant_nodes.index(target_node)
    similarities[target_index] = -np.inf
    
    # 找到最相似的 top_k 个节点
    top_k_indices = similarities.argsort()[-top_k:][::-1]
    top_k_similarities = similarities[top_k_indices]
    top_k_nodes = [relevant_nodes[i] for i in top_k_indices]

    # 将最相似的节点转换为ID
    top_k_ids = [node_index.index(node) for node in top_k_nodes]

    return top_k_ids, top_k_nodes, top_k_similarities

def plot_similarity_heatmap(nodes, model, output_path, font_path):
    # 加载自定义字体
    prop = font_manager.FontProperties(fname=font_path)
    
    # 计算相似度矩阵
    vectors = np.array([model.wv[node] for node in nodes])
    similarity_matrix = cosine_similarity(vectors)

    # 画热力图
    plt.figure(figsize=(20, 16))
    sns.heatmap(similarity_matrix, 
                xticklabels=nodes, 
                yticklabels=nodes, 
                cmap="RdYlBu_r",  # 使用红黄蓝颜色渐变
                annot=False, 
                square=True,  # 确保每个单元格是正方形
                cbar_kws={'label': 'similarity'}, 
                linewidths=.5)  # 增加单元格之间的线条分割
    
    plt.title("theme without weight", fontproperties=prop, fontsize=20, pad=20)
    plt.xticks(rotation=45, ha="right", fontproperties=prop, fontsize=12)
    plt.yticks(rotation=0, fontproperties=prop, fontsize=12)
    
    plt.tight_layout()  # 调整布局以适应标签
    plt.savefig(output_path)
    plt.show()

if __name__ == '__main__':
    original_content, node_index = load_cora_data(cfg.data_path)
    
    # 加载已训练的DeepWalk模型
    model_path = cfg.model_path
    model = load_model(model_path)
    # 打印模型中的所有节点
    all_nodes = model.wv.index_to_key
    print("模型词汇表中的所有节点:")
    print(all_nodes)

    # 分别处理 topic_ 和 theme_ 的节点
    topic_results = []
    theme_nodes = []

    for idx, target_node in enumerate(node_index):
        if target_node.startswith('topic_'):
            top_k_ids, top_k_nodes, top_k_similarities = find_similar_vectors(model, target_node, node_index)
            
            result = {
                'id': idx+1,
                '节点实际内容': target_node,
                '最相似的前5个节点id及相似度': [(top_k_ids[i], top_k_similarities[i]) for i in range(5)]
            }
            for i in range(5):
                result[f'最相似的节点 {i+1}'] = top_k_nodes[i]
            
            topic_results.append(result)
        elif target_node.startswith('theme_'):
            theme_nodes.append(target_node)

    # 保存 topic_ 节点的相似度结果
    topic_results_df = pd.DataFrame(topic_results)
    topic_output_file_path = '/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/deepwalk_alldata_topic1.xlsx'
    topic_results_df.to_excel(topic_output_file_path, index=False)
    print(f"Topic results have been saved to {topic_output_file_path}.")

    # 画 theme_ 节点的相似度热力图
    if len(theme_nodes) == 61:
        heatmap_output_path = '/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/theme_similarity_819.png'
        plot_similarity_heatmap(theme_nodes, model, heatmap_output_path, cfg.font_path)
        print(f"Theme similarity heatmap saved to {heatmap_output_path}.")
    else:
        print(f"Error: Expected 61 theme_ nodes, but found {len(theme_nodes)}.")
# Out:
# 模型词汇表中的所有节点:
# ['theme_旅游与交通', 'theme_人际交往', 'theme_兴趣与爱好', 'theme_日常活动', 'theme_工作', 'theme_节假日活动', 'theme_计划与安排', 'theme_安全与救护', 'theme_活动安排', 'theme_学习', 'theme_历史与社会', 'theme_地点', 'theme_购物', 'theme_卫生与健康', 'theme_服务', 'theme_个人信息', 'theme_学校', 'theme_求助', 'theme_亲情', 'theme_文娱与体育', 'theme_人物描写', 'theme_居住情况', 'theme_家庭、朋友与周围的人', 'theme_科普知识与现代技术', 'theme_物品', 'theme_娱乐', 'theme_经历', 'theme_教育', 'theme_通讯', 'theme_文学与艺术', 'theme_自我介绍', 'theme_邀请', 'theme_情感与情绪', 'theme_人物故事', 'theme_时间', 'theme_饮食', 'theme_天气', 'theme_压力', 'theme_影视形象', 'theme_动物', 'theme_世界与环境', 'theme_友情', 'theme_周围的环境', 'topic_个人特征与生活', 'theme_媒体', 'topic_学生与教育', 'topic_日常生活', 'theme_环保', 'topic_家庭与日常事务', 'topic_社交与活动', 'topic_学习与阅读', 'topic_个人与社交', 'topic_交通', 'topic_家庭', 'theme_服装', 'topic_体育与健身', 'topic_餐饮与购物', 'theme_科学幻想', 'theme_自然', 'topic_教育与学生', 'topic_位置与导航', 'topic_公共设施与行为', 'topic_家庭与儿童', 'topic_影视与娱乐', 'topic_教育与校园生活', 'topic_教育及校园生活', 'topic_个人生活', 'topic_休闲与旅游', 'topic_旅行与假期', 'topic_社交沟通', 'topic_人物与关系', 'topic_人际关系', 'topic_学习与成长', 'topic_职业与学习', 'topic_个人与生活', 'topic_生活方式', 'theme_数字', 'topic_娱乐与体育', 'topic_休闲与艺术', 'topic_时间与日常活动', 'topic_学校和学生生活', 'topic_日常活动与情绪', 'theme_热点话题', 'topic_冒险与娱乐', 'theme_年龄', 'topic_沟通与交流', 'topic_社区与环境', 'topic_教育与校园', 'theme_历史和地理', 'topic_人际关系与活动', 'theme_阅读理解', 'topic_兴趣与活动', 'topic_娱乐与休闲', 'theme_故事与诗歌', 'topic_教育与学习', 'topic_宠物', 'topic_健康与医疗', 'topic_方位与位置', 'topic_旅行与节日', 'topic_规划与计划', 'topic_人物与家庭', 'topic_兴趣', 'topic_旅行与交通', 'topic_文化与教育', 'topic_节日与活动', 'topic_个人爱好与活动', 'topic_交流与沟通', 'topic_教育与知识', 'topic_环境与保护', 'topic_物品与描述', 'topic_职业和职业相关', 'topic_学习与教育', 'topic_自然与环境', 'topic_购物', 'topic_生活与娱乐', 'topic_居住与生活', 'topic_旅行', 'topic_日常交流', 'topic_生活指南', 'topic_家庭与家庭生活', 'topic_物品与识别', 'topic_生活与家庭', 'topic_厨房与家务', 'topic_日程与安排', 'topic_活动与休闲', 'topic_人际关系与礼仪', 'theme_颜色', 'topic_家庭与日常生活', 'topic_个人与经历', 'theme_包容', 'topic_居住与生活环境', 'topic_规章与管理', 'topic_社交与个人事务', 'topic_旅游与计划', 'topic_社交与互动', 'topic_饮食与烹饪', 'topic_探索与位置', 'topic_职场与教育', 'topic_餐饮与用餐', 'topic_健康', 'topic_娱乐与表演', 'topic_购物与日常生活', 'topic_学生生活', 'topic_科学', 'topic_服饰与购物', 'topic_动物与自然', 'topic_公益与环保', 'topic_文学与阅读', 'topic_教育与课堂', 'topic_教育与职业发展', 'topic_娱乐与社交', 'topic_计算机与互联网', 'topic_人际交流', 'topic_老年与生活', 'topic_场所与方向指引', 'topic_体育与竞技', 'topic_生活与健康', 'topic_冒险与生存', 'topic_文艺与阅读', 'topic_购物与消费习惯', 'topic_休闲与娱乐', 'topic_旅行与地点', 'topic_安全与规则', 'topic_体育与运动', 'topic_描述与特征', 'topic_日常生活与互动', 'topic_文化', 'topic_时间与计划', 'topic_娱乐', 'topic_节日与礼物', 'topic_旅游与娱乐', 'theme_烦恼', 'topic_购物交易', 'topic_活动与事件', 'topic_文化与习俗', 'topic_校园与学校', 'topic_宠物与自然', 'topic_日常生活与社交', 'topic_活动策划', 'topic_兴趣与娱乐活动', 'topic_天气与活动', 'topic_个人与家庭', 'topic_语言与交流', 'topic_媒体与阅读', 'topic_物品与所有权', 'topic_健康与生活', 'topic_个人兴趣', 'topic_饮食与健康', 'topic_旅行与户外活动', 'topic_个人经历与感受', 'topic_天气与自然', 'topic_教育与阅读', 'topic_社交互动', 'topic_时间与日程', 'topic_家庭与生活', 'topic_节日与庆祝', 'topic_宠物与动物', 'topic_医疗与健康', 'topic_教育与职业', 'topic_竞赛与发明', 'topic_交通与旅行', 'topic_餐饮', 'topic_家庭活动', 'topic_学业与校内事务', 'topic_人物与人际关系', 'topic_个人通讯与人际交流', 'topic_家居与日常', 'topic_文化与学习', 'topic_个人与兴趣', 'topic_环保与动物', 'topic_学术与教育', 'topic_交通与出行', 'topic_庆祝与祝福', 'topic_教育', 'topic_四季与活动', 'topic_旅游与文化', 'topic_家庭与教育', 'topic_娱乐与比赛', 'topic_职业与工作', 'topic_饮食', 'topic_饮食与餐饮', 'topic_时尚与衣物', 'topic_时尚与购物', 'topic_科学与技术', 'topic_季节与生活', 'topic_美食与生活', 'topic_娱乐活动', 'topic_应急与健康', 'topic_文化与生活', 'topic_时间与活动安排', 'topic_历史与教育', 'topic_失物与合作', 'topic_家庭与关系', 'topic_娱乐与休闲生活', 'topic_寻物与描述', 'topic_紧急处理', 'topic_自然现象与描述', 'topic_数学与描述', 'topic_学校与学术', 'topic_人物及描述', 'topic_旅游与户外活动', 'topic_宠物护理', 'topic_位置与指引', 'topic_教育与生活', 'topic_餐饮与服务', 'topic_娱乐与生活', 'topic_娱乐与文化', 'topic_职业与日常生活', 'topic_食物与饮食', 'topic_名人与知识', 'topic_行为', 'topic_生活和家庭', 'theme_寓言故事', 'topic_儿童与娱乐', 'topic_农业与自然', 'topic_社交与礼仪', 'topic_联系方式', 'topic_职业与计划', 'topic_教育与艺术', 'topic_物品管理', 'topic_个人生活与时间', 'topic_生活与消费', 'topic_人物特征', 'topic_个人与描述', 'topic_文艺与娱乐', 'topic_确认与安排', 'topic_家庭与个人生活', 'topic_人际交往', 'topic_科技与通信', 'topic_出行与旅游', 'theme_知识', 'topic_自然与科学', ' ...
# Topic results have been saved to /mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/deepwalk_alldata_topic1.xlsx.
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20146 (\N{CJK UNIFIED IDEOGRAPH-4EB2}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24773 (\N{CJK UNIFIED IDEOGRAPH-60C5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29289 (\N{CJK UNIFIED IDEOGRAPH-7269}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21697 (\N{CJK UNIFIED IDEOGRAPH-54C1}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 39278 (\N{CJK UNIFIED IDEOGRAPH-996E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 39135 (\N{CJK UNIFIED IDEOGRAPH-98DF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20154 (\N{CJK UNIFIED IDEOGRAPH-4EBA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25551 (\N{CJK UNIFIED IDEOGRAPH-63CF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20889 (\N{CJK UNIFIED IDEOGRAPH-5199}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23621 (\N{CJK UNIFIED IDEOGRAPH-5C45}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20303 (\N{CJK UNIFIED IDEOGRAPH-4F4F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20917 (\N{CJK UNIFIED IDEOGRAPH-51B5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24120 (\N{CJK UNIFIED IDEOGRAPH-5E38}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27963 (\N{CJK UNIFIED IDEOGRAPH-6D3B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21160 (\N{CJK UNIFIED IDEOGRAPH-52A8}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21355 (\N{CJK UNIFIED IDEOGRAPH-536B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29983 (\N{CJK UNIFIED IDEOGRAPH-751F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20581 (\N{CJK UNIFIED IDEOGRAPH-5065}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24247 (\N{CJK UNIFIED IDEOGRAPH-5EB7}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25945 (\N{CJK UNIFIED IDEOGRAPH-6559}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 32946 (\N{CJK UNIFIED IDEOGRAPH-80B2}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 36141 (\N{CJK UNIFIED IDEOGRAPH-8D2D}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26053 (\N{CJK UNIFIED IDEOGRAPH-65C5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 28216 (\N{CJK UNIFIED IDEOGRAPH-6E38}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20132 (\N{CJK UNIFIED IDEOGRAPH-4EA4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 36890 (\N{CJK UNIFIED IDEOGRAPH-901A}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27714 (\N{CJK UNIFIED IDEOGRAPH-6C42}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21161 (\N{CJK UNIFIED IDEOGRAPH-52A9}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 32463 (\N{CJK UNIFIED IDEOGRAPH-7ECF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21382 (\N{CJK UNIFIED IDEOGRAPH-5386}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20852 (\N{CJK UNIFIED IDEOGRAPH-5174}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 36259 (\N{CJK UNIFIED IDEOGRAPH-8DA3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29233 (\N{CJK UNIFIED IDEOGRAPH-7231}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22909 (\N{CJK UNIFIED IDEOGRAPH-597D}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 33410 (\N{CJK UNIFIED IDEOGRAPH-8282}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20551 (\N{CJK UNIFIED IDEOGRAPH-5047}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23433 (\N{CJK UNIFIED IDEOGRAPH-5B89}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25490 (\N{CJK UNIFIED IDEOGRAPH-6392}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21490 (\N{CJK UNIFIED IDEOGRAPH-53F2}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 31038 (\N{CJK UNIFIED IDEOGRAPH-793E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20250 (\N{CJK UNIFIED IDEOGRAPH-4F1A}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24448 (\N{CJK UNIFIED IDEOGRAPH-5F80}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27668 (\N{CJK UNIFIED IDEOGRAPH-6C14}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23398 (\N{CJK UNIFIED IDEOGRAPH-5B66}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20064 (\N{CJK UNIFIED IDEOGRAPH-4E60}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29615 (\N{CJK UNIFIED IDEOGRAPH-73AF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20445 (\N{CJK UNIFIED IDEOGRAPH-4FDD}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35745 (\N{CJK UNIFIED IDEOGRAPH-8BA1}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21010 (\N{CJK UNIFIED IDEOGRAPH-5212}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26381 (\N{CJK UNIFIED IDEOGRAPH-670D}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21153 (\N{CJK UNIFIED IDEOGRAPH-52A1}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23478 (\N{CJK UNIFIED IDEOGRAPH-5BB6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24237 (\N{CJK UNIFIED IDEOGRAPH-5EAD}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26379 (\N{CJK UNIFIED IDEOGRAPH-670B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21451 (\N{CJK UNIFIED IDEOGRAPH-53CB}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21608 (\N{CJK UNIFIED IDEOGRAPH-5468}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22260 (\N{CJK UNIFIED IDEOGRAPH-56F4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24037 (\N{CJK UNIFIED IDEOGRAPH-5DE5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20316 (\N{CJK UNIFIED IDEOGRAPH-4F5C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22320 (\N{CJK UNIFIED IDEOGRAPH-5730}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 28857 (\N{CJK UNIFIED IDEOGRAPH-70B9}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 33258 (\N{CJK UNIFIED IDEOGRAPH-81EA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25105 (\N{CJK UNIFIED IDEOGRAPH-6211}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20171 (\N{CJK UNIFIED IDEOGRAPH-4ECB}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 32461 (\N{CJK UNIFIED IDEOGRAPH-7ECD}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20010 (\N{CJK UNIFIED IDEOGRAPH-4E2A}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24687 (\N{CJK UNIFIED IDEOGRAPH-606F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 40836 (\N{CJK UNIFIED IDEOGRAPH-9F84}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23089 (\N{CJK UNIFIED IDEOGRAPH-5A31}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20048 (\N{CJK UNIFIED IDEOGRAPH-4E50}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20307 (\N{CJK UNIFIED IDEOGRAPH-4F53}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 33402 (\N{CJK UNIFIED IDEOGRAPH-827A}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26415 (\N{CJK UNIFIED IDEOGRAPH-672F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26657 (\N{CJK UNIFIED IDEOGRAPH-6821}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24433 (\N{CJK UNIFIED IDEOGRAPH-5F71}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35270 (\N{CJK UNIFIED IDEOGRAPH-89C6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35937 (\N{CJK UNIFIED IDEOGRAPH-8C61}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 28902 (\N{CJK UNIFIED IDEOGRAPH-70E6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24700 (\N{CJK UNIFIED IDEOGRAPH-607C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35759 (\N{CJK UNIFIED IDEOGRAPH-8BAF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20840 (\N{CJK UNIFIED IDEOGRAPH-5168}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25937 (\N{CJK UNIFIED IDEOGRAPH-6551}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25252 (\N{CJK UNIFIED IDEOGRAPH-62A4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 38405 (\N{CJK UNIFIED IDEOGRAPH-9605}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35835 (\N{CJK UNIFIED IDEOGRAPH-8BFB}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29702 (\N{CJK UNIFIED IDEOGRAPH-7406}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35299 (\N{CJK UNIFIED IDEOGRAPH-89E3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 36992 (\N{CJK UNIFIED IDEOGRAPH-9080}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35831 (\N{CJK UNIFIED IDEOGRAPH-8BF7}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 19990 (\N{CJK UNIFIED IDEOGRAPH-4E16}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 30028 (\N{CJK UNIFIED IDEOGRAPH-754C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22659 (\N{CJK UNIFIED IDEOGRAPH-5883}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23186 (\N{CJK UNIFIED IDEOGRAPH-5A92}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23383 (\N{CJK UNIFIED IDEOGRAPH-5B57}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21644 (\N{CJK UNIFIED IDEOGRAPH-548C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 39068 (\N{CJK UNIFIED IDEOGRAPH-989C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 33394 (\N{CJK UNIFIED IDEOGRAPH-8272}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25925 (\N{CJK UNIFIED IDEOGRAPH-6545}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20107 (\N{CJK UNIFIED IDEOGRAPH-4E8B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 31185 (\N{CJK UNIFIED IDEOGRAPH-79D1}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26222 (\N{CJK UNIFIED IDEOGRAPH-666E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 30693 (\N{CJK UNIFIED IDEOGRAPH-77E5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35782 (\N{CJK UNIFIED IDEOGRAPH-8BC6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29616 (\N{CJK UNIFIED IDEOGRAPH-73B0}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20195 (\N{CJK UNIFIED IDEOGRAPH-4EE3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25216 (\N{CJK UNIFIED IDEOGRAPH-6280}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24863 (\N{CJK UNIFIED IDEOGRAPH-611F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 32490 (\N{CJK UNIFIED IDEOGRAPH-7EEA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24187 (\N{CJK UNIFIED IDEOGRAPH-5E7B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24819 (\N{CJK UNIFIED IDEOGRAPH-60F3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21387 (\N{CJK UNIFIED IDEOGRAPH-538B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35013 (\N{CJK UNIFIED IDEOGRAPH-88C5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21171 (\N{CJK UNIFIED IDEOGRAPH-52B3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 28982 (\N{CJK UNIFIED IDEOGRAPH-7136}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35805 (\N{CJK UNIFIED IDEOGRAPH-8BDD}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 39064 (\N{CJK UNIFIED IDEOGRAPH-9898}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21253 (\N{CJK UNIFIED IDEOGRAPH-5305}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23481 (\N{CJK UNIFIED IDEOGRAPH-5BB9}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23507 (\N{CJK UNIFIED IDEOGRAPH-5BD3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35328 (\N{CJK UNIFIED IDEOGRAPH-8A00}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35799 (\N{CJK UNIFIED IDEOGRAPH-8BD7}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27468 (\N{CJK UNIFIED IDEOGRAPH-6B4C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 31070 (\N{CJK UNIFIED IDEOGRAPH-795E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20256 (\N{CJK UNIFIED IDEOGRAPH-4F20}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35828 (\N{CJK UNIFIED IDEOGRAPH-8BF4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# Theme similarity heatmap saved to /mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/theme_similarity_819.png.

# %%
import os
import pandas as pd
import numpy as np
import torch
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager

class configs():
    def __init__(self):
        self.data_path = r'/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data'
        self.model_path = r'/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/deepwalk819_alldata1.model'
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.font_path = r'/mnt/new_pfs/liming_team/auroraX/chenlong/testdata/simhei.ttf'  # 字体路径
        self.similarity_threshold = 0.5

cfg = configs()

def load_cora_data(data_path='/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data'):
    content_df = pd.read_csv(os.path.join(data_path, "cora_819_alldata.content"), delimiter="\t", header=None)
    content_df.set_index(0, inplace=True)
    index = content_df.index.astype(str).tolist()  # 使用字符串索引

    original_content = content_df.iloc[:, -1].tolist()

    return original_content, index

def load_model(model_path):
    model = Word2Vec.load(model_path)
    return model

def normalize_similarity(similarities, max_value, preserve_diagonal=False):
    min_sim = np.min(similarities)
    max_sim = np.max(similarities)
    # 如果最大值和最小值相等，则所有值都是一样的，直接返回max_value
    if max_sim == min_sim:
        return np.full_like(similarities, max_value)
    normalized_similarities = max_value * (similarities - min_sim) / (max_sim - min_sim)
    
    # 如果要保留对角线的值，恢复对角线元素
    if preserve_diagonal:
        np.fill_diagonal(normalized_similarities, max_value)
    
    return normalized_similarities

def plot_similarity_heatmap(nodes, model, output_path, font_path, similarity_threshold):
    # 加载自定义字体
    prop = font_manager.FontProperties(fname=font_path)
    
    # 计算相似度矩阵
    vectors = np.array([model.wv[node] for node in nodes])
    similarity_matrix = cosine_similarity(vectors)
    print(similarity_matrix)
    
    # 设置对角线元素为相似度阈值
    np.fill_diagonal(similarity_matrix, similarity_threshold)

    # 将相似度矩阵中大于相似度阈值的值设置为相似度阈值
    similarity_matrix[similarity_matrix > similarity_threshold] = similarity_threshold

    # 归一化相似度到0到相似度阈值之间，同时保留对角线元素
    similarity_matrix = normalize_similarity(similarity_matrix, similarity_threshold, preserve_diagonal=True)
    print(similarity_matrix)
    
    # 画热力图
    plt.figure(figsize=(20, 16))
    sns.heatmap(similarity_matrix, 
                xticklabels=nodes, 
                yticklabels=nodes, 
                cmap="RdYlBu_r",  # 使用红黄蓝颜色渐变
                annot=False, 
                square=True,  # 确保每个单元格是正方形
                cbar_kws={'label': 'similarity'}, 
                linewidths=.5)  # 增加单元格之间的线条分割
    
    plt.title("theme without weight", fontproperties=prop, fontsize=20, pad=20)
    plt.xticks(rotation=45, ha="right", fontproperties=prop, fontsize=12)
    plt.yticks(rotation=0, fontproperties=prop, fontsize=12)
    
    plt.tight_layout()  # 调整布局以适应标签
    plt.savefig(output_path)
    plt.show()

if __name__ == '__main__':
    original_content, node_index = load_cora_data(cfg.data_path)
    
    # 加载已训练的DeepWalk模型
    model_path = cfg.model_path
    model = load_model(model_path)
    # 打印模型中的所有节点
    all_nodes = model.wv.index_to_key
    print("模型词汇表中的所有节点:")
    print(all_nodes)

    # 处理 theme_ 的节点
    theme_nodes = []

    for idx, target_node in enumerate(node_index):
        if target_node.startswith('theme_'):
            theme_nodes.append(target_node)

    if len(theme_nodes) == 61:
        heatmap_output_path = '/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/theme_similarity_819_05.png'
        plot_similarity_heatmap(theme_nodes, model, heatmap_output_path, cfg.font_path, cfg.similarity_threshold)
        print(f"Theme similarity heatmap saved to {heatmap_output_path}.")
    else:
        print(f"Error: Expected 61 theme_ nodes, but found {len(theme_nodes)}.")
# Out:
# 模型词汇表中的所有节点:
# ['theme_旅游与交通', 'theme_人际交往', 'theme_兴趣与爱好', 'theme_日常活动', 'theme_工作', 'theme_节假日活动', 'theme_计划与安排', 'theme_安全与救护', 'theme_活动安排', 'theme_学习', 'theme_历史与社会', 'theme_地点', 'theme_购物', 'theme_卫生与健康', 'theme_服务', 'theme_个人信息', 'theme_学校', 'theme_求助', 'theme_亲情', 'theme_文娱与体育', 'theme_人物描写', 'theme_居住情况', 'theme_家庭、朋友与周围的人', 'theme_科普知识与现代技术', 'theme_物品', 'theme_娱乐', 'theme_经历', 'theme_教育', 'theme_通讯', 'theme_文学与艺术', 'theme_自我介绍', 'theme_邀请', 'theme_情感与情绪', 'theme_人物故事', 'theme_时间', 'theme_饮食', 'theme_天气', 'theme_压力', 'theme_影视形象', 'theme_动物', 'theme_世界与环境', 'theme_友情', 'theme_周围的环境', 'topic_个人特征与生活', 'theme_媒体', 'topic_学生与教育', 'topic_日常生活', 'theme_环保', 'topic_家庭与日常事务', 'topic_社交与活动', 'topic_学习与阅读', 'topic_个人与社交', 'topic_交通', 'topic_家庭', 'theme_服装', 'topic_体育与健身', 'topic_餐饮与购物', 'theme_科学幻想', 'theme_自然', 'topic_教育与学生', 'topic_位置与导航', 'topic_公共设施与行为', 'topic_家庭与儿童', 'topic_影视与娱乐', 'topic_教育与校园生活', 'topic_教育及校园生活', 'topic_个人生活', 'topic_休闲与旅游', 'topic_旅行与假期', 'topic_社交沟通', 'topic_人物与关系', 'topic_人际关系', 'topic_学习与成长', 'topic_职业与学习', 'topic_个人与生活', 'topic_生活方式', 'theme_数字', 'topic_娱乐与体育', 'topic_休闲与艺术', 'topic_时间与日常活动', 'topic_学校和学生生活', 'topic_日常活动与情绪', 'theme_热点话题', 'topic_冒险与娱乐', 'theme_年龄', 'topic_沟通与交流', 'topic_社区与环境', 'topic_教育与校园', 'theme_历史和地理', 'topic_人际关系与活动', 'theme_阅读理解', 'topic_兴趣与活动', 'topic_娱乐与休闲', 'theme_故事与诗歌', 'topic_教育与学习', 'topic_宠物', 'topic_健康与医疗', 'topic_方位与位置', 'topic_旅行与节日', 'topic_规划与计划', 'topic_人物与家庭', 'topic_兴趣', 'topic_旅行与交通', 'topic_文化与教育', 'topic_节日与活动', 'topic_个人爱好与活动', 'topic_交流与沟通', 'topic_教育与知识', 'topic_环境与保护', 'topic_物品与描述', 'topic_职业和职业相关', 'topic_学习与教育', 'topic_自然与环境', 'topic_购物', 'topic_生活与娱乐', 'topic_居住与生活', 'topic_旅行', 'topic_日常交流', 'topic_生活指南', 'topic_家庭与家庭生活', 'topic_物品与识别', 'topic_生活与家庭', 'topic_厨房与家务', 'topic_日程与安排', 'topic_活动与休闲', 'topic_人际关系与礼仪', 'theme_颜色', 'topic_家庭与日常生活', 'topic_个人与经历', 'theme_包容', 'topic_居住与生活环境', 'topic_规章与管理', 'topic_社交与个人事务', 'topic_旅游与计划', 'topic_社交与互动', 'topic_饮食与烹饪', 'topic_探索与位置', 'topic_职场与教育', 'topic_餐饮与用餐', 'topic_健康', 'topic_娱乐与表演', 'topic_购物与日常生活', 'topic_学生生活', 'topic_科学', 'topic_服饰与购物', 'topic_动物与自然', 'topic_公益与环保', 'topic_文学与阅读', 'topic_教育与课堂', 'topic_教育与职业发展', 'topic_娱乐与社交', 'topic_计算机与互联网', 'topic_人际交流', 'topic_老年与生活', 'topic_场所与方向指引', 'topic_体育与竞技', 'topic_生活与健康', 'topic_冒险与生存', 'topic_文艺与阅读', 'topic_购物与消费习惯', 'topic_休闲与娱乐', 'topic_旅行与地点', 'topic_安全与规则', 'topic_体育与运动', 'topic_描述与特征', 'topic_日常生活与互动', 'topic_文化', 'topic_时间与计划', 'topic_娱乐', 'topic_节日与礼物', 'topic_旅游与娱乐', 'theme_烦恼', 'topic_购物交易', 'topic_活动与事件', 'topic_文化与习俗', 'topic_校园与学校', 'topic_宠物与自然', 'topic_日常生活与社交', 'topic_活动策划', 'topic_兴趣与娱乐活动', 'topic_天气与活动', 'topic_个人与家庭', 'topic_语言与交流', 'topic_媒体与阅读', 'topic_物品与所有权', 'topic_健康与生活', 'topic_个人兴趣', 'topic_饮食与健康', 'topic_旅行与户外活动', 'topic_个人经历与感受', 'topic_天气与自然', 'topic_教育与阅读', 'topic_社交互动', 'topic_时间与日程', 'topic_家庭与生活', 'topic_节日与庆祝', 'topic_宠物与动物', 'topic_医疗与健康', 'topic_教育与职业', 'topic_竞赛与发明', 'topic_交通与旅行', 'topic_餐饮', 'topic_家庭活动', 'topic_学业与校内事务', 'topic_人物与人际关系', 'topic_个人通讯与人际交流', 'topic_家居与日常', 'topic_文化与学习', 'topic_个人与兴趣', 'topic_环保与动物', 'topic_学术与教育', 'topic_交通与出行', 'topic_庆祝与祝福', 'topic_教育', 'topic_四季与活动', 'topic_旅游与文化', 'topic_家庭与教育', 'topic_娱乐与比赛', 'topic_职业与工作', 'topic_饮食', 'topic_饮食与餐饮', 'topic_时尚与衣物', 'topic_时尚与购物', 'topic_科学与技术', 'topic_季节与生活', 'topic_美食与生活', 'topic_娱乐活动', 'topic_应急与健康', 'topic_文化与生活', 'topic_时间与活动安排', 'topic_历史与教育', 'topic_失物与合作', 'topic_家庭与关系', 'topic_娱乐与休闲生活', 'topic_寻物与描述', 'topic_紧急处理', 'topic_自然现象与描述', 'topic_数学与描述', 'topic_学校与学术', 'topic_人物及描述', 'topic_旅游与户外活动', 'topic_宠物护理', 'topic_位置与指引', 'topic_教育与生活', 'topic_餐饮与服务', 'topic_娱乐与生活', 'topic_娱乐与文化', 'topic_职业与日常生活', 'topic_食物与饮食', 'topic_名人与知识', 'topic_行为', 'topic_生活和家庭', 'theme_寓言故事', 'topic_儿童与娱乐', 'topic_农业与自然', 'topic_社交与礼仪', 'topic_联系方式', 'topic_职业与计划', 'topic_教育与艺术', 'topic_物品管理', 'topic_个人生活与时间', 'topic_生活与消费', 'topic_人物特征', 'topic_个人与描述', 'topic_文艺与娱乐', 'topic_确认与安排', 'topic_家庭与个人生活', 'topic_人际交往', 'topic_科技与通信', 'topic_出行与旅游', 'theme_知识', 'topic_自然与科学', ' ...
# [[1.0000001  0.05061634 0.11899423 ... 0.06432766 0.04359371 0.08462863]
#  [0.05061634 1.0000002  0.07560641 ... 0.15432534 0.19162393 0.15480365]
#  [0.11899423 0.07560641 1.         ... 0.0859693  0.05977505 0.04680258]
#  ...
#  [0.06432766 0.15432534 0.0859693  ... 1.0000001  0.12737815 0.05997074]
#  [0.04359371 0.19162393 0.05977505 ... 0.12737815 0.9999999  0.14676183]
#  [0.08462863 0.15480365 0.04680258 ... 0.05997074 0.14676183 0.9999998 ]]
# [[0.5        0.07269668 0.13771483 ... 0.08573429 0.0660191  0.10503778]
#  [0.07269668 0.5        0.09645887 ... 0.17130996 0.2067759  0.17176478]
#  [0.13771483 0.09645887 0.5        ... 0.10631258 0.08140537 0.06907031]
#  ...
#  [0.08573429 0.17130996 0.10631258 ... 0.5        0.14568682 0.08159145]
#  [0.0660191  0.2067759  0.08140537 ... 0.14568682 0.5        0.1641181 ]
#  [0.10503778 0.17176478 0.06907031 ... 0.08159145 0.1641181  0.5       ]]
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20146 (\N{CJK UNIFIED IDEOGRAPH-4EB2}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24773 (\N{CJK UNIFIED IDEOGRAPH-60C5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29289 (\N{CJK UNIFIED IDEOGRAPH-7269}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21697 (\N{CJK UNIFIED IDEOGRAPH-54C1}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 39278 (\N{CJK UNIFIED IDEOGRAPH-996E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 39135 (\N{CJK UNIFIED IDEOGRAPH-98DF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20154 (\N{CJK UNIFIED IDEOGRAPH-4EBA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25551 (\N{CJK UNIFIED IDEOGRAPH-63CF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20889 (\N{CJK UNIFIED IDEOGRAPH-5199}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23621 (\N{CJK UNIFIED IDEOGRAPH-5C45}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20303 (\N{CJK UNIFIED IDEOGRAPH-4F4F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20917 (\N{CJK UNIFIED IDEOGRAPH-51B5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24120 (\N{CJK UNIFIED IDEOGRAPH-5E38}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27963 (\N{CJK UNIFIED IDEOGRAPH-6D3B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21160 (\N{CJK UNIFIED IDEOGRAPH-52A8}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21355 (\N{CJK UNIFIED IDEOGRAPH-536B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29983 (\N{CJK UNIFIED IDEOGRAPH-751F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20581 (\N{CJK UNIFIED IDEOGRAPH-5065}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24247 (\N{CJK UNIFIED IDEOGRAPH-5EB7}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25945 (\N{CJK UNIFIED IDEOGRAPH-6559}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 32946 (\N{CJK UNIFIED IDEOGRAPH-80B2}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 36141 (\N{CJK UNIFIED IDEOGRAPH-8D2D}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26053 (\N{CJK UNIFIED IDEOGRAPH-65C5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 28216 (\N{CJK UNIFIED IDEOGRAPH-6E38}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20132 (\N{CJK UNIFIED IDEOGRAPH-4EA4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 36890 (\N{CJK UNIFIED IDEOGRAPH-901A}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27714 (\N{CJK UNIFIED IDEOGRAPH-6C42}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21161 (\N{CJK UNIFIED IDEOGRAPH-52A9}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 32463 (\N{CJK UNIFIED IDEOGRAPH-7ECF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21382 (\N{CJK UNIFIED IDEOGRAPH-5386}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20852 (\N{CJK UNIFIED IDEOGRAPH-5174}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 36259 (\N{CJK UNIFIED IDEOGRAPH-8DA3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29233 (\N{CJK UNIFIED IDEOGRAPH-7231}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22909 (\N{CJK UNIFIED IDEOGRAPH-597D}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 33410 (\N{CJK UNIFIED IDEOGRAPH-8282}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20551 (\N{CJK UNIFIED IDEOGRAPH-5047}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23433 (\N{CJK UNIFIED IDEOGRAPH-5B89}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25490 (\N{CJK UNIFIED IDEOGRAPH-6392}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21490 (\N{CJK UNIFIED IDEOGRAPH-53F2}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 31038 (\N{CJK UNIFIED IDEOGRAPH-793E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20250 (\N{CJK UNIFIED IDEOGRAPH-4F1A}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24448 (\N{CJK UNIFIED IDEOGRAPH-5F80}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27668 (\N{CJK UNIFIED IDEOGRAPH-6C14}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23398 (\N{CJK UNIFIED IDEOGRAPH-5B66}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20064 (\N{CJK UNIFIED IDEOGRAPH-4E60}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29615 (\N{CJK UNIFIED IDEOGRAPH-73AF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20445 (\N{CJK UNIFIED IDEOGRAPH-4FDD}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35745 (\N{CJK UNIFIED IDEOGRAPH-8BA1}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21010 (\N{CJK UNIFIED IDEOGRAPH-5212}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26381 (\N{CJK UNIFIED IDEOGRAPH-670D}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21153 (\N{CJK UNIFIED IDEOGRAPH-52A1}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23478 (\N{CJK UNIFIED IDEOGRAPH-5BB6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24237 (\N{CJK UNIFIED IDEOGRAPH-5EAD}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26379 (\N{CJK UNIFIED IDEOGRAPH-670B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21451 (\N{CJK UNIFIED IDEOGRAPH-53CB}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21608 (\N{CJK UNIFIED IDEOGRAPH-5468}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22260 (\N{CJK UNIFIED IDEOGRAPH-56F4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24037 (\N{CJK UNIFIED IDEOGRAPH-5DE5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20316 (\N{CJK UNIFIED IDEOGRAPH-4F5C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22320 (\N{CJK UNIFIED IDEOGRAPH-5730}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 28857 (\N{CJK UNIFIED IDEOGRAPH-70B9}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 33258 (\N{CJK UNIFIED IDEOGRAPH-81EA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25105 (\N{CJK UNIFIED IDEOGRAPH-6211}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20171 (\N{CJK UNIFIED IDEOGRAPH-4ECB}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 32461 (\N{CJK UNIFIED IDEOGRAPH-7ECD}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20010 (\N{CJK UNIFIED IDEOGRAPH-4E2A}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24687 (\N{CJK UNIFIED IDEOGRAPH-606F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 40836 (\N{CJK UNIFIED IDEOGRAPH-9F84}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23089 (\N{CJK UNIFIED IDEOGRAPH-5A31}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20048 (\N{CJK UNIFIED IDEOGRAPH-4E50}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20307 (\N{CJK UNIFIED IDEOGRAPH-4F53}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 33402 (\N{CJK UNIFIED IDEOGRAPH-827A}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26415 (\N{CJK UNIFIED IDEOGRAPH-672F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26657 (\N{CJK UNIFIED IDEOGRAPH-6821}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24433 (\N{CJK UNIFIED IDEOGRAPH-5F71}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35270 (\N{CJK UNIFIED IDEOGRAPH-89C6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24418 (\N{CJK UNIFIED IDEOGRAPH-5F62}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35937 (\N{CJK UNIFIED IDEOGRAPH-8C61}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 28902 (\N{CJK UNIFIED IDEOGRAPH-70E6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24700 (\N{CJK UNIFIED IDEOGRAPH-607C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35759 (\N{CJK UNIFIED IDEOGRAPH-8BAF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20840 (\N{CJK UNIFIED IDEOGRAPH-5168}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25937 (\N{CJK UNIFIED IDEOGRAPH-6551}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25252 (\N{CJK UNIFIED IDEOGRAPH-62A4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 38405 (\N{CJK UNIFIED IDEOGRAPH-9605}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35835 (\N{CJK UNIFIED IDEOGRAPH-8BFB}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29702 (\N{CJK UNIFIED IDEOGRAPH-7406}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35299 (\N{CJK UNIFIED IDEOGRAPH-89E3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 36992 (\N{CJK UNIFIED IDEOGRAPH-9080}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35831 (\N{CJK UNIFIED IDEOGRAPH-8BF7}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 19990 (\N{CJK UNIFIED IDEOGRAPH-4E16}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 30028 (\N{CJK UNIFIED IDEOGRAPH-754C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22659 (\N{CJK UNIFIED IDEOGRAPH-5883}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23186 (\N{CJK UNIFIED IDEOGRAPH-5A92}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23383 (\N{CJK UNIFIED IDEOGRAPH-5B57}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21644 (\N{CJK UNIFIED IDEOGRAPH-548C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 39068 (\N{CJK UNIFIED IDEOGRAPH-989C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 33394 (\N{CJK UNIFIED IDEOGRAPH-8272}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25925 (\N{CJK UNIFIED IDEOGRAPH-6545}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20107 (\N{CJK UNIFIED IDEOGRAPH-4E8B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 31185 (\N{CJK UNIFIED IDEOGRAPH-79D1}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26222 (\N{CJK UNIFIED IDEOGRAPH-666E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 30693 (\N{CJK UNIFIED IDEOGRAPH-77E5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35782 (\N{CJK UNIFIED IDEOGRAPH-8BC6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29616 (\N{CJK UNIFIED IDEOGRAPH-73B0}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20195 (\N{CJK UNIFIED IDEOGRAPH-4EE3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25216 (\N{CJK UNIFIED IDEOGRAPH-6280}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24863 (\N{CJK UNIFIED IDEOGRAPH-611F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 32490 (\N{CJK UNIFIED IDEOGRAPH-7EEA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24187 (\N{CJK UNIFIED IDEOGRAPH-5E7B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24819 (\N{CJK UNIFIED IDEOGRAPH-60F3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21387 (\N{CJK UNIFIED IDEOGRAPH-538B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35013 (\N{CJK UNIFIED IDEOGRAPH-88C5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21171 (\N{CJK UNIFIED IDEOGRAPH-52B3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 28982 (\N{CJK UNIFIED IDEOGRAPH-7136}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35805 (\N{CJK UNIFIED IDEOGRAPH-8BDD}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 39064 (\N{CJK UNIFIED IDEOGRAPH-9898}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21253 (\N{CJK UNIFIED IDEOGRAPH-5305}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23481 (\N{CJK UNIFIED IDEOGRAPH-5BB9}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23507 (\N{CJK UNIFIED IDEOGRAPH-5BD3}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35328 (\N{CJK UNIFIED IDEOGRAPH-8A00}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35799 (\N{CJK UNIFIED IDEOGRAPH-8BD7}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27468 (\N{CJK UNIFIED IDEOGRAPH-6B4C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 31070 (\N{CJK UNIFIED IDEOGRAPH-795E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20256 (\N{CJK UNIFIED IDEOGRAPH-4F20}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /AuroraX-00/share_v4/chenlong/enter/envs/recom/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 35828 (\N{CJK UNIFIED IDEOGRAPH-8BF4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# Theme similarity heatmap saved to /mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/theme_similarity_819_05.png.

# %% [markdown]
# ### 细节调整

# %%
import json
import numpy as np
import networkx as nx
from sklearn.preprocessing import LabelEncoder

# 假设jsonl文件为 "data.jsonl"
jsonl_file = "/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/en_title_100w_audio_filter_v2.jsonl"

# 读取jsonl文件并提取theme_1和topic的关系
edges = []
themes = set()
topics = set()
edge_weights = {}

with open(jsonl_file, 'r') as f:
    for line in f:
        data = json.loads(line)
        theme_1 = f"theme_{data['theme_1']}"  # 添加前缀 "theme_"
        topic = f"topic_{data['topic']}"  # 添加前缀 "topic_"
        print(f"Processed: theme_1 = {theme_1}, topic = {topic}")

        edge = (theme_1, topic)
        # 如果边已存在，则增加权重
        if edge in edge_weights:
            edge_weights[edge] += 1
        else:
            edge_weights[edge] = 1
        
        themes.add(theme_1)
        topics.add(topic)

# 创建一个双向图
G = nx.Graph()

# 根据加权边添加到图中
for edge, weight in edge_weights.items():
    G.add_edge(edge[0], edge[1], weight=weight)

# 为每个节点添加标签
for theme in themes:
    G.nodes[theme]['label'] = 'theme'  

for topic in topics:
    G.nodes[topic]['label'] = 'topic' 

# 构建节点特征矩阵和邻接矩阵
nodes = list(G.nodes)
adj_matrix = nx.adjacency_matrix(G, nodelist=nodes).todense()

label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(nodes)
num_classes = len(label_encoder.classes_)
feature_matrix = np.eye(num_classes)[labels]

# 保存加权的 cora.cites 文件
cites_lines = []
for edge in G.edges(data=True):
    cites_line = f"{edge[0]}\t{edge[1]}\t{edge[2]['weight']}"
    cites_lines.append(cites_line)

with open("/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/cora_weight.cites", "w") as f:
    for line in cites_lines:
        f.write(line + '\n')

# 保存 cora.content 文件
content_lines = []
node_ids = list(G.nodes)
for node_id in node_ids:
    attributes = [1 if G.has_edge(node_id, other_id) or G.has_edge(other_id, node_id) else 0 for other_id in node_ids]
    data = G.nodes[node_id]
    label = data['label']
    content_line = f"{node_id}\t{' '.join(map(str, attributes))}\t{label}"
    content_lines.append(content_line)

with open("/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/cora_weight.content", "w") as f:
    for line in content_lines:
        f.write(line + '\n')

print("cora.cites 和 cora.content 文件已保存。")
# Out:
# Processed: theme_1 = theme_亲情, topic = topic_家庭与关系
# Processed: theme_1 = theme_物品, topic = topic_物品与消费
# Processed: theme_1 = theme_饮食, topic = topic_饮食与健康
# Processed: theme_1 = theme_人物描写, topic = topic_个人特征与生活
# Processed: theme_1 = theme_亲情, topic = topic_家庭与关系
# Processed: theme_1 = theme_居住情况, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_饮食, topic = topic_饮食与健康
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食与健康
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与关系
# Processed: theme_1 = theme_教育, topic = topic_个人特征与生活
# Processed: theme_1 = theme_购物, topic = topic_物品与消费
# Processed: theme_1 = theme_旅游与交通, topic = topic_出行与旅游
# Processed: theme_1 = theme_求助, topic = topic_物品与消费
# Processed: theme_1 = theme_求助, topic = topic_物品与消费
# Processed: theme_1 = theme_动物, topic = topic_动物与自然
# Processed: theme_1 = theme_求助, topic = topic_物品与消费
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_运动与健康
# Processed: theme_1 = theme_节假日活动, topic = topic_娱乐与休闲
# Processed: theme_1 = theme_节假日活动, topic = topic_文化与社交
# Processed: theme_1 = theme_活动安排, topic = topic_社会与社区
# Processed: theme_1 = theme_活动安排, topic = topic_文化与社交
# Processed: theme_1 = theme_历史与社会, topic = topic_社会与社区
# Processed: theme_1 = theme_人际交往, topic = topic_社会与社区
# Processed: theme_1 = theme_天气, topic = topic_运动与健康
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_社会与社区
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_文化与社交
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_文化与社交
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_文化与社交
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_文化与社交
# Processed: theme_1 = theme_人物描写, topic = topic_个人特征与生活
# Processed: theme_1 = theme_活动安排, topic = topic_文化与社交
# Processed: theme_1 = theme_学习, topic = topic_文化与社交
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_文化与社交
# Processed: theme_1 = theme_卫生与健康, topic = topic_运动与健康
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_旅游与交通, topic = topic_娱乐与休闲
# Processed: theme_1 = theme_计划与安排, topic = topic_运动与健康
# Processed: theme_1 = theme_旅游与交通, topic = topic_娱乐与休闲
# Processed: theme_1 = theme_卫生与健康, topic = topic_运动与健康
# Processed: theme_1 = theme_历史与社会, topic = topic_文化与社交
# Processed: theme_1 = theme_历史与社会, topic = topic_文化与社交
# Processed: theme_1 = theme_历史与社会, topic = topic_文化与社交
# Processed: theme_1 = theme_服务, topic = topic_社会与社区
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_社会与社区
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_计划与安排, topic = topic_旅游与计划
# Processed: theme_1 = theme_工作, topic = topic_志愿与资金
# Processed: theme_1 = theme_地点, topic = topic_旅游与计划
# Processed: theme_1 = theme_地点, topic = topic_旅游与计划
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康与健身
# Processed: theme_1 = theme_自我介绍, topic = topic_教育与背景
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康与健身
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康与健身
# Processed: theme_1 = theme_教育, topic = topic_教育与背景
# Processed: theme_1 = theme_个人信息, topic = topic_教育与背景
# Processed: theme_1 = theme_学习, topic = topic_教育与背景
# Processed: theme_1 = theme_工作, topic = topic_教育与背景
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_活动安排, topic = topic_志愿与资金
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_学习, topic = topic_教育与背景
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_年龄, topic = topic_家庭与个人
# Processed: theme_1 = theme_人际交往, topic = topic_购物与交易
# Processed: theme_1 = theme_娱乐, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育与运动
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与个人
# Processed: theme_1 = theme_文学与艺术, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_文学与艺术, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_地点, topic = topic_生活服务
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与个人
# Processed: theme_1 = theme_求助, topic = topic_生活服务
# Processed: theme_1 = theme_人际交往, topic = topic_家庭与个人
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_旅游与交通, topic = topic_生活服务
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_影视形象, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_烦恼, topic = topic_家庭与个人
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育与运动
# Processed: theme_1 = theme_旅游与交通, topic = topic_生活服务
# Processed: theme_1 = theme_人际交往, topic = topic_人际关系与礼仪
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与个人
# Processed: theme_1 = theme_人物描写, topic = topic_个人特征与生活
# Processed: theme_1 = theme_个人信息, topic = topic_人际关系与礼仪
# Processed: theme_1 = theme_时间, topic = topic_时间与活动安排
# Processed: theme_1 = theme_求助, topic = topic_信息传递与表达
# Processed: theme_1 = theme_影视形象, topic = topic_信息传递与表达
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_地点, topic = topic_休闲与生活
# Processed: theme_1 = theme_经历, topic = topic_人际关系与礼仪
# Processed: theme_1 = theme_通讯, topic = topic_时间与活动安排
# Processed: theme_1 = theme_通讯, topic = topic_时间与活动安排
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_个人特征与生活
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_个人特征与生活
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_个人特征与生活
# Processed: theme_1 = theme_节假日活动, topic = topic_人际关系与礼仪
# Processed: theme_1 = theme_计划与安排, topic = topic_旅游与计划
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康与健身
# Processed: theme_1 = theme_经历, topic = topic_人际关系与礼仪
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_动物, topic = topic_休闲与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_人际关系与礼仪
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康与健身
# Processed: theme_1 = theme_服务, topic = topic_人际关系与礼仪
# Processed: theme_1 = theme_工作, topic = topic_个人特征与生活
# Processed: theme_1 = theme_服务, topic = topic_学习与阅读
# Processed: theme_1 = theme_服务, topic = topic_学习与阅读
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_学习, topic = topic_学习与阅读
# Processed: theme_1 = theme_计划与安排, topic = topic_时间与活动安排
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_安全与救护, topic = topic_时间与活动安排
# Processed: theme_1 = theme_活动安排, topic = topic_时间与活动安排
# Processed: theme_1 = theme_饮食, topic = topic_休闲与生活
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_节假日活动, topic = topic_时间与活动安排
# Processed: theme_1 = theme_节假日活动, topic = topic_节日庆祝
# Processed: theme_1 = theme_居住情况, topic = topic_家庭
# Processed: theme_1 = theme_居住情况, topic = topic_家庭
# Processed: theme_1 = theme_居住情况, topic = topic_家庭
# Processed: theme_1 = theme_计划与安排, topic = topic_时间与活动安排
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_出行与旅游
# Processed: theme_1 = theme_日常活动, topic = topic_时间与活动安排
# Processed: theme_1 = theme_文娱与体育, topic = topic_娱乐与体育
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_人际交往, topic = topic_文化
# Processed: theme_1 = theme_自我介绍, topic = topic_教育与背景
# Processed: theme_1 = theme_日常活动, topic = topic_时间与活动安排
# Processed: theme_1 = theme_天气, topic = topic_自然与环境
# Processed: theme_1 = theme_旅游与交通, topic = topic_时间与活动安排
# Processed: theme_1 = theme_物品, topic = topic_物品与识别
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_人际交往, topic = topic_媒体与阅读
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_阅读理解, topic = topic_媒体与阅读
# Processed: theme_1 = theme_影视形象, topic = topic_媒体与阅读
# Processed: theme_1 = theme_影视形象, topic = topic_媒体与阅读
# Processed: theme_1 = theme_影视形象, topic = topic_媒体与阅读
# Processed: theme_1 = theme_影视形象, topic = topic_媒体与阅读
# Processed: theme_1 = theme_动物, topic = topic_节日庆祝
# Processed: theme_1 = theme_邀请, topic = topic_个人特征与生活
# Processed: theme_1 = theme_计划与安排, topic = topic_旅行与交通
# Processed: theme_1 = theme_购物, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_个人信息, topic = topic_家庭
# Processed: theme_1 = theme_工作, topic = topic_教育
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_文娱与体育, topic = topic_个人特征与生活
# Processed: theme_1 = theme_服务, topic = topic_社会与社区
# Processed: theme_1 = theme_求助, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_地点, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_学习, topic = topic_旅行与交通
# Processed: theme_1 = theme_学习, topic = topic_旅行与交通
# Processed: theme_1 = theme_学习, topic = topic_旅行与交通
# Processed: theme_1 = theme_学习, topic = topic_旅行与交通
# Processed: theme_1 = theme_学习, topic = topic_旅行与交通
# Processed: theme_1 = theme_购物, topic = topic_个人特征与生活
# Processed: theme_1 = theme_活动安排, topic = topic_文化与社交
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_地点, topic = topic_休闲与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_出行与旅游
# Processed: theme_1 = theme_时间, topic = topic_时间与计划
# Processed: theme_1 = theme_阅读理解, topic = topic_教育
# Processed: theme_1 = theme_人际交往, topic = topic_个人特征与生活
# Processed: theme_1 = theme_地点, topic = topic_教育
# Processed: theme_1 = theme_教育, topic = topic_家庭
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_求助, topic = topic_个人特征与生活
# Processed: theme_1 = theme_服务, topic = topic_个人特征与生活
# Processed: theme_1 = theme_娱乐, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_娱乐, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_娱乐, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_文娱与体育, topic = topic_娱乐与体育
# Processed: theme_1 = theme_活动安排, topic = topic_家庭
# Processed: theme_1 = theme_世界与环境, topic = topic_自然与环境
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_计划与安排, topic = topic_时间与活动安排
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食与健康
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_娱乐与体育
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_文化
# Processed: theme_1 = theme_学校, topic = topic_教育与职业
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_天气, topic = topic_气候与环境
# Processed: theme_1 = theme_日常活动, topic = topic_家庭
# Processed: theme_1 = theme_旅游与交通, topic = topic_娱乐与体育
# Processed: theme_1 = theme_动物, topic = topic_自然与环境
# Processed: theme_1 = theme_购物, topic = topic_饮食
# Processed: theme_1 = theme_天气, topic = topic_气候与环境
# Processed: theme_1 = theme_人际交往, topic = topic_文化
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_周围的环境, topic = topic_教育与职业
# Processed: theme_1 = theme_旅游与交通, topic = topic_娱乐与体育
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_动物, topic = topic_自然与环境
# Processed: theme_1 = theme_服务, topic = topic_个人特征与生活
# Processed: theme_1 = theme_服务, topic = topic_个人特征与生活
# Processed: theme_1 = theme_饮食, topic = topic_饮食
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_旅游与交通, topic = topic_文化
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_动物, topic = topic_饮食
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_家庭与安全
# Processed: theme_1 = theme_安全与救护, topic = topic_时间与活动安排
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食
# Processed: theme_1 = theme_环保, topic = topic_气候与环境
# Processed: theme_1 = theme_历史与社会, topic = topic_家庭与安全
# Processed: theme_1 = theme_历史与社会, topic = topic_家庭与安全
# Processed: theme_1 = theme_学校, topic = topic_教育与职业
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_工作, topic = topic_教育与职业
# Processed: theme_1 = theme_活动安排, topic = topic_教育与职业
# Processed: theme_1 = theme_活动安排, topic = topic_教育与职业
# Processed: theme_1 = theme_工作, topic = topic_教育
# Processed: theme_1 = theme_人物描写, topic = topic_个人特征与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅游与文化
# Processed: theme_1 = theme_文学与艺术, topic = topic_旅游与文化
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_文学与艺术, topic = topic_旅游与文化
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与出行
# Processed: theme_1 = theme_媒体, topic = topic_气候与环境
# Processed: theme_1 = theme_购物, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_文学与艺术, topic = topic_旅游与文化
# Processed: theme_1 = theme_地点, topic = topic_旅游与文化
# Processed: theme_1 = theme_饮食, topic = topic_饮食
# Processed: theme_1 = theme_活动安排, topic = topic_教育与职业
# Processed: theme_1 = theme_卫生与健康, topic = topic_家庭与个人
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_物品, topic = topic_购物与交易
# Processed: theme_1 = theme_学校, topic = topic_教育与职业
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与出行
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与出行
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_活动安排, topic = topic_教育与职业
# Processed: theme_1 = theme_旅游与交通, topic = topic_生活与设施
# Processed: theme_1 = theme_计划与安排, topic = topic_旅游与计划
# Processed: theme_1 = theme_数字, topic = topic_生活与设施
# Processed: theme_1 = theme_计划与安排, topic = topic_生活与设施
# Processed: theme_1 = theme_学校, topic = topic_教育与职业
# Processed: theme_1 = theme_旅游与交通, topic = topic_出行与旅游
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_个人信息, topic = topic_家庭
# Processed: theme_1 = theme_动物, topic = topic_文化
# Processed: theme_1 = theme_人物描写, topic = topic_文化
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_计划与安排, topic = topic_生活与设施
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与个人
# Processed: theme_1 = theme_教育, topic = topic_教育与职业
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_地点, topic = topic_生活与设施
# Processed: theme_1 = theme_经历, topic = topic_交通与出行
# Processed: theme_1 = theme_自我介绍, topic = topic_教育与背景
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_家庭与个人
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_家庭与个人
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_家庭与个人
# Processed: theme_1 = theme_活动安排, topic = topic_家庭
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_社会与社区
# Processed: theme_1 = theme_天气, topic = topic_交通与出行
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与出行
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_人物描写, topic = topic_个人特征与生活
# Processed: theme_1 = theme_服务, topic = topic_个人特征与生活
# Processed: theme_1 = theme_人物描写, topic = topic_家庭与个人
# Processed: theme_1 = theme_计划与安排, topic = topic_家庭与个人
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_文娱与体育, topic = topic_娱乐活动
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与出行
# Processed: theme_1 = theme_人际交往, topic = topic_社交沟通
# Processed: theme_1 = theme_人际交往, topic = topic_社交沟通
# Processed: theme_1 = theme_活动安排, topic = topic_家庭与个人
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_人际交往, topic = topic_社交沟通
# Processed: theme_1 = theme_历史和地理, topic = topic_生活其他
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_旅游与交通, topic = topic_出行与旅游
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_邀请, topic = topic_个人特征与生活
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_工作, topic = topic_社交沟通
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_活动安排, topic = topic_社会与社区
# Processed: theme_1 = theme_旅游与交通, topic = topic_家庭与个人
# Processed: theme_1 = theme_服务, topic = topic_生活其他
# Processed: theme_1 = theme_服务, topic = topic_生活其他
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_社会与社区
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_生活其他
# Processed: theme_1 = theme_学习, topic = topic_生活其他
# Processed: theme_1 = theme_计划与安排, topic = topic_生活与设施
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与出行
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_人物描写, topic = topic_家庭与个人
# Processed: theme_1 = theme_人物描写, topic = topic_家庭与个人
# Processed: theme_1 = theme_人物描写, topic = topic_家庭与个人
# Processed: theme_1 = theme_人物描写, topic = topic_家庭与个人
# Processed: theme_1 = theme_文娱与体育, topic = topic_个人特征与生活
# Processed: theme_1 = theme_活动安排, topic = topic_娱乐活动
# Processed: theme_1 = theme_娱乐, topic = topic_娱乐活动
# Processed: theme_1 = theme_工作, topic = topic_教育
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_娱乐活动
# Processed: theme_1 = theme_文娱与体育, topic = topic_娱乐活动
# Processed: theme_1 = theme_影视形象, topic = topic_娱乐活动
# Processed: theme_1 = theme_教育, topic = topic_社交沟通
# Processed: theme_1 = theme_服务, topic = topic_社会与社区
# Processed: theme_1 = theme_购物, topic = topic_经济交易
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_文娱与体育, topic = topic_教育
# Processed: theme_1 = theme_通讯, topic = topic_社交沟通
# Processed: theme_1 = theme_购物, topic = topic_文化
# Processed: theme_1 = theme_文娱与体育, topic = topic_娱乐活动
# Processed: theme_1 = theme_文娱与体育, topic = topic_娱乐活动
# Processed: theme_1 = theme_饮食, topic = topic_社交沟通
# Processed: theme_1 = theme_学习, topic = topic_社会
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_活动安排, topic = topic_教育
# Processed: theme_1 = theme_计划与安排, topic = topic_社会
# Processed: theme_1 = theme_服务, topic = topic_经济交易
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_求助, topic = topic_社会
# Processed: theme_1 = theme_文娱与体育, topic = topic_娱乐与体育
# Processed: theme_1 = theme_文娱与体育, topic = topic_娱乐与体育
# Processed: theme_1 = theme_文娱与体育, topic = topic_娱乐与体育
# Processed: theme_1 = theme_学习, topic = topic_教育
# Processed: theme_1 = theme_旅游与交通, topic = topic_娱乐与体育
# Processed: theme_1 = theme_旅游与交通, topic = topic_娱乐活动
# Processed: theme_1 = theme_教育, topic = topic_经济交易
# Processed: theme_1 = theme_教育, topic = topic_经济交易
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食与健康
# Processed: theme_1 = theme_工作, topic = topic_职业和生涯
# Processed: theme_1 = theme_人际交往, topic = topic_社会
# Processed: theme_1 = theme_计划与安排, topic = topic_社会
# Processed: theme_1 = theme_节假日活动, topic = topic_娱乐与休闲
# Processed: theme_1 = theme_人际交往, topic = topic_家庭
# Processed: theme_1 = theme_计划与安排, topic = topic_时间与计划
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_数字, topic = topic_自然与环境
# Processed: theme_1 = theme_旅游与交通, topic = topic_自然与环境
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与出行
# Processed: theme_1 = theme_居住情况, topic = topic_家庭
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_假期与娱乐
# Processed: theme_1 = theme_历史和地理, topic = topic_自然与环境
# Processed: theme_1 = theme_时间, topic = topic_方位与位置
# Processed: theme_1 = theme_旅游与交通, topic = topic_出行与旅游
# Processed: theme_1 = theme_地点, topic = topic_旅游与计划
# Processed: theme_1 = theme_学习, topic = topic_教育
# Processed: theme_1 = theme_时间, topic = topic_时间与计划
# Processed: theme_1 = theme_购物, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_购物, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_人际交往, topic = topic_个人特征与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_方位与位置
# Processed: theme_1 = theme_周围的环境, topic = topic_方位与位置
# Processed: theme_1 = theme_卫生与健康, topic = topic_家庭与安全
# Processed: theme_1 = theme_卫生与健康, topic = topic_家庭
# Processed: theme_1 = theme_颜色, topic = topic_个人生活与时间
# Processed: theme_1 = theme_时间, topic = topic_家庭与安全
# Processed: theme_1 = theme_娱乐, topic = topic_假期与娱乐
# Processed: theme_1 = theme_天气, topic = topic_运动与健康
# Processed: theme_1 = theme_地点, topic = topic_休闲与生活
# Processed: theme_1 = theme_计划与安排, topic = topic_时间与活动安排
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与安全
# Processed: theme_1 = theme_人物故事, topic = topic_教育
# Processed: theme_1 = theme_人物故事, topic = topic_教育
# Processed: theme_1 = theme_人物故事, topic = topic_教育
# Processed: theme_1 = theme_人物故事, topic = topic_教育
# Processed: theme_1 = theme_人物故事, topic = topic_教育
# Processed: theme_1 = theme_人物故事, topic = topic_教育
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_户外与自然
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_服务, topic = topic_职业与工作
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与出行
# Processed: theme_1 = theme_物品, topic = topic_物品与描述
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_居住情况, topic = topic_家庭与个人
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_求助, topic = topic_旅行与交通
# Processed: theme_1 = theme_学校, topic = topic_教育与校园
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_购物, topic = topic_购物与经济
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_节假日活动, topic = topic_文化
# Processed: theme_1 = theme_友情, topic = topic_家庭与个人
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_节假日活动, topic = topic_文化
# Processed: theme_1 = theme_动物, topic = topic_户外与自然
# Processed: theme_1 = theme_动物, topic = topic_户外与自然
# Processed: theme_1 = theme_动物, topic = topic_户外与自然
# Processed: theme_1 = theme_动物, topic = topic_户外与自然
# Processed: theme_1 = theme_工作, topic = topic_职业与工作
# Processed: theme_1 = theme_天气, topic = topic_户外与自然
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_日常活动, topic = topic_教育与校园
# Processed: theme_1 = theme_节假日活动, topic = topic_教育与校园
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_旅游与交通, topic = topic_教育与校园
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_人际交往, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_教育与校园
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_购物, topic = topic_购物与经济
# Processed: theme_1 = theme_活动安排, topic = topic_教育与校园
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_个人信息, topic = topic_购物与经济
# Processed: theme_1 = theme_计划与安排, topic = topic_生活与设施
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_时间, topic = topic_旅行与交通
# Processed: theme_1 = theme_科普知识与现代技术, topic = topic_科技
# Processed: theme_1 = theme_娱乐, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_娱乐, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_人物描写, topic = topic_文化
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_文化
# Processed: theme_1 = theme_居住情况, topic = topic_文化
# Processed: theme_1 = theme_人际交往, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_影视形象, topic = topic_娱乐与休闲生活
# Processed: theme_1 = theme_购物, topic = topic_购物与经济
# Processed: theme_1 = theme_安全与救护, topic = topic_旅行与交通
# Processed: theme_1 = theme_旅游与交通, topic = topic_娱乐与休闲
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_教育与校园
# Processed: theme_1 = theme_文娱与体育, topic = topic_健康与健身
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食
# Processed: theme_1 = theme_娱乐, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康与健身
# Processed: theme_1 = theme_文娱与体育, topic = topic_健康与健身
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_服务, topic = topic_社会与社区
# Processed: theme_1 = theme_科普知识与现代技术, topic = topic_科技
# Processed: theme_1 = theme_娱乐, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_节假日活动, topic = topic_娱乐与休闲生活
# Processed: theme_1 = theme_邀请, topic = topic_娱乐与体育
# Processed: theme_1 = theme_天气, topic = topic_气候与环境
# Processed: theme_1 = theme_旅游与交通, topic = topic_自然与环境
# Processed: theme_1 = theme_旅游与交通, topic = topic_自然与环境
# Processed: theme_1 = theme_旅游与交通, topic = topic_自然与环境
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_天气, topic = topic_自然与环境
# Processed: theme_1 = theme_天气, topic = topic_运动与健康
# Processed: theme_1 = theme_人物描写, topic = topic_文化
# Processed: theme_1 = theme_人物描写, topic = topic_文化
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_年龄, topic = topic_时间与计划
# Processed: theme_1 = theme_学校, topic = topic_娱乐与体育
# Processed: theme_1 = theme_动物, topic = topic_自然与环境
# Processed: theme_1 = theme_人际交往, topic = topic_礼仪与交流
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康
# Processed: theme_1 = theme_文学与艺术, topic = topic_文化
# Processed: theme_1 = theme_日常活动, topic = topic_娱乐与体育
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_天气, topic = topic_自然与环境
# Processed: theme_1 = theme_个人信息, topic = topic_个人与家庭
# Processed: theme_1 = theme_情感与情绪, topic = topic_娱乐与体育
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与个人
# Processed: theme_1 = theme_求助, topic = topic_旅行与交通
# Processed: theme_1 = theme_地点, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_饮食, topic = topic_饮食与餐饮
# Processed: theme_1 = theme_人物描写, topic = topic_人物与人际关系
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_文化
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_人物描写, topic = topic_人物与人际关系
# Processed: theme_1 = theme_求助, topic = topic_礼仪与交流
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_教育与校园
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与关系
# Processed: theme_1 = theme_娱乐, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_时间, topic = topic_教育与校园
# Processed: theme_1 = theme_人物描写, topic = topic_个人特征与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_生活与设施
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_数字, topic = topic_教育与校园
# Processed: theme_1 = theme_周围的环境, topic = topic_生活与健康
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_个人特征与生活
# Processed: theme_1 = theme_学校, topic = topic_教育与校园
# Processed: theme_1 = theme_卫生与健康, topic = topic_生活与健康
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_地点, topic = topic_生活与健康
# Processed: theme_1 = theme_旅游与交通, topic = topic_娱乐与体育
# Processed: theme_1 = theme_活动安排, topic = topic_时间与活动安排
# Processed: theme_1 = theme_时间, topic = topic_时间与计划
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_环保, topic = topic_时间与计划
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_日常活动, topic = topic_生活与健康
# Processed: theme_1 = theme_物品, topic = topic_物品与描述
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_颜色, topic = topic_社交
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_人际交往, topic = topic_人物与人际关系
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_活动安排, topic = topic_社会
# Processed: theme_1 = theme_时间, topic = topic_自然与环境
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_历史与社会, topic = topic_文化
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与出行
# Processed: theme_1 = theme_天气, topic = topic_自然与环境
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_社会
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_节假日活动, topic = topic_文化
# Processed: theme_1 = theme_学校, topic = topic_教育与校园
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_天气, topic = topic_运动与健康
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_安全与救护, topic = topic_健康
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_教育, topic = topic_教育与校园
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_工作, topic = topic_教育
# Processed: theme_1 = theme_饮食, topic = topic_饮食
# Processed: theme_1 = theme_地点, topic = topic_物品与描述
# Processed: theme_1 = theme_个人信息, topic = topic_家庭
# Processed: theme_1 = theme_个人信息, topic = topic_家庭
# Processed: theme_1 = theme_个人信息, topic = topic_家庭
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_地点, topic = topic_旅行与交通
# Processed: theme_1 = theme_旅游与交通, topic = topic_人际关系与礼仪
# Processed: theme_1 = theme_活动安排, topic = topic_人物与人际关系
# Processed: theme_1 = theme_个人信息, topic = topic_节日与礼物
# Processed: theme_1 = theme_个人信息, topic = topic_节日与礼物
# Processed: theme_1 = theme_人际交往, topic = topic_人物与人际关系
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_节假日活动, topic = topic_时间与活动安排
# Processed: theme_1 = theme_居住情况, topic = topic_家庭
# Processed: theme_1 = theme_居住情况, topic = topic_家庭
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_人际交往, topic = topic_问题与事件
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与个人
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_求助, topic = topic_物品与识别
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_文娱与体育, topic = topic_家庭
# Processed: theme_1 = theme_日常活动, topic = topic_家庭
# Processed: theme_1 = theme_工作, topic = topic_职业
# Processed: theme_1 = theme_工作, topic = topic_职业
# Processed: theme_1 = theme_工作, topic = topic_职业
# Processed: theme_1 = theme_工作, topic = topic_职业
# Processed: theme_1 = theme_工作, topic = topic_职业
# Processed: theme_1 = theme_工作, topic = topic_职业
# Processed: theme_1 = theme_人际交往, topic = topic_家庭
# Processed: theme_1 = theme_工作, topic = topic_职业
# Processed: theme_1 = theme_工作, topic = topic_职业
# Processed: theme_1 = theme_工作, topic = topic_职业
# Processed: theme_1 = theme_科普知识与现代技术, topic = topic_物品与识别
# Processed: theme_1 = theme_地点, topic = topic_家庭
# Processed: theme_1 = theme_购物, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_户外与自然
# Processed: theme_1 = theme_旅游与交通, topic = topic_家庭
# Processed: theme_1 = theme_娱乐, topic = topic_家庭
# Processed: theme_1 = theme_地点, topic = topic_物品与识别
# Processed: theme_1 = theme_日常活动, topic = topic_家庭
# Processed: theme_1 = theme_居住情况, topic = topic_购物与交易
# Processed: theme_1 = theme_学校, topic = topic_教育
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_活动安排, topic = topic_教育与职业
# Processed: theme_1 = theme_安全与救护, topic = topic_问题与事件
# Processed: theme_1 = theme_个人信息, topic = topic_职业与计划
# Processed: theme_1 = theme_个人信息, topic = topic_职业与计划
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_人物描写, topic = topic_个人特征与生活
# Processed: theme_1 = theme_饮食, topic = topic_家庭
# Processed: theme_1 = theme_工作, topic = topic_教育与背景
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_科学幻想, topic = topic_职业与计划
# Processed: theme_1 = theme_科学幻想, topic = topic_职业与计划
# Processed: theme_1 = theme_科学幻想, topic = topic_职业与计划
# Processed: theme_1 = theme_科学幻想, topic = topic_职业与计划
# Processed: theme_1 = theme_科学幻想, topic = topic_职业与计划
# Processed: theme_1 = theme_计划与安排, topic = topic_个人特征与生活
# Processed: theme_1 = theme_世界与环境, topic = topic_旅行与交通
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_计划与安排, topic = topic_旅行与交通
# Processed: theme_1 = theme_计划与安排, topic = topic_时间与活动安排
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_学校, topic = topic_教育与校园
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_友情, topic = topic_人际关系
# Processed: theme_1 = theme_工作, topic = topic_职业与计划
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_计划与安排, topic = topic_旅游与计划
# Processed: theme_1 = theme_计划与安排, topic = topic_生活与设施
# Processed: theme_1 = theme_旅游与交通, topic = topic_出行与旅游
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_活动安排, topic = topic_文化与社交
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_学习, topic = topic_职业与计划
# Processed: theme_1 = theme_时间, topic = topic_个人特征与生活
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_文化
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与关系
# Processed: theme_1 = theme_计划与安排, topic = topic_旅行与交通
# Processed: theme_1 = theme_旅游与交通, topic = topic_个人特征与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_日常活动, topic = topic_教育与校园
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_活动安排, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_节假日活动, topic = topic_文化与社交
# Processed: theme_1 = theme_文学与艺术, topic = topic_休闲与艺术
# Processed: theme_1 = theme_影视形象, topic = topic_休闲与艺术
# Processed: theme_1 = theme_动物, topic = topic_宠物护理
# Processed: theme_1 = theme_活动安排, topic = topic_活动策划
# Processed: theme_1 = theme_旅游与交通, topic = topic_活动策划
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_科普知识与现代技术, topic = topic_科技与网络
# Processed: theme_1 = theme_计划与安排, topic = topic_旅行与交通
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_教育与校园
# Processed: theme_1 = theme_通讯, topic = topic_人际交流
# Processed: theme_1 = theme_亲情, topic = topic_人际交流
# Processed: theme_1 = theme_亲情, topic = topic_人际交流
# Processed: theme_1 = theme_亲情, topic = topic_人际交流
# Processed: theme_1 = theme_亲情, topic = topic_人际交流
# Processed: theme_1 = theme_天气, topic = topic_自然与环境
# Processed: theme_1 = theme_天气, topic = topic_自然与环境
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_家庭与安全
# Processed: theme_1 = theme_饮食, topic = topic_饮食与文化
# Processed: theme_1 = theme_天气, topic = topic_气候与环境
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_人际交流
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_人际交往, topic = topic_人际交流
# Processed: theme_1 = theme_日常活动, topic = topic_教育与校园
# Processed: theme_1 = theme_学习, topic = topic_教育
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_服务, topic = topic_个人特征与生活
# Processed: theme_1 = theme_个人信息, topic = topic_人际交流
# Processed: theme_1 = theme_饮食, topic = topic_饮食与健康
# Processed: theme_1 = theme_人际交往, topic = topic_社交沟通
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_历史与社会, topic = topic_饮食与文化
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_人际交往, topic = topic_教育与校园
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_邀请, topic = topic_人际交流
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_服务, topic = topic_公共服务
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_计划与安排, topic = topic_旅行与交通
# Processed: theme_1 = theme_亲情, topic = topic_家庭与关系
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_教育与校园
# Processed: theme_1 = theme_安全与救护, topic = topic_安全与动物
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_节假日活动, topic = topic_文化与社交
# Processed: theme_1 = theme_求助, topic = topic_旅行与交通
# Processed: theme_1 = theme_文娱与体育, topic = topic_艺术与娱乐
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_旅游与交通, topic = topic_文化
# Processed: theme_1 = theme_物品, topic = topic_生活与消费
# Processed: theme_1 = theme_活动安排, topic = topic_休闲与活动
# Processed: theme_1 = theme_旅游与交通, topic = topic_休闲与活动
# Processed: theme_1 = theme_娱乐, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_物品, topic = topic_物品与描述
# Processed: theme_1 = theme_居住情况, topic = topic_家庭
# Processed: theme_1 = theme_个人信息, topic = topic_生活与消费
# Processed: theme_1 = theme_旅游与交通, topic = topic_农业与自然
# Processed: theme_1 = theme_工作, topic = topic_职业
# Processed: theme_1 = theme_工作, topic = topic_职业
# Processed: theme_1 = theme_购物, topic = topic_生活与消费
# Processed: theme_1 = theme_周围的环境, topic = topic_农业与自然
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_服务, topic = topic_社会与社区
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_影视形象, topic = topic_艺术与娱乐
# Processed: theme_1 = theme_购物, topic = topic_生活与消费
# Processed: theme_1 = theme_周围的环境, topic = topic_居住与环境
# Processed: theme_1 = theme_科普知识与现代技术, topic = topic_科技
# Processed: theme_1 = theme_人际交往, topic = topic_家庭
# Processed: theme_1 = theme_动物, topic = topic_安全与动物
# Processed: theme_1 = theme_学习, topic = topic_教育
# Processed: theme_1 = theme_工作, topic = topic_教育
# Processed: theme_1 = theme_学习, topic = topic_教育
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_娱乐, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_人物描写, topic = topic_家庭与个人
# Processed: theme_1 = theme_时间, topic = topic_交通与时间管理
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_户外与自然
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_户外与自然
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_户外与自然
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_户外与自然
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_户外与自然
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与时间管理
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与时间管理
# Processed: theme_1 = theme_压力, topic = topic_教育
# Processed: theme_1 = theme_动物, topic = topic_自然与环境
# Processed: theme_1 = theme_地点, topic = topic_社会与生活
# Processed: theme_1 = theme_安全与救护, topic = topic_问题与事件
# Processed: theme_1 = theme_安全与救护, topic = topic_问题与事件
# Processed: theme_1 = theme_服装, topic = topic_时尚
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_安全与救护, topic = topic_问题与事件
# Processed: theme_1 = theme_邀请, topic = topic_社会与生活
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_社会与生活
# Processed: theme_1 = theme_安全与救护, topic = topic_问题与事件
# Processed: theme_1 = theme_学习, topic = topic_教育
# Processed: theme_1 = theme_科学幻想, topic = topic_科技
# Processed: theme_1 = theme_节假日活动, topic = topic_文化
# Processed: theme_1 = theme_科普知识与现代技术, topic = topic_科技
# Processed: theme_1 = theme_工作, topic = topic_教育
# Processed: theme_1 = theme_工作, topic = topic_教育
# Processed: theme_1 = theme_工作, topic = topic_教育
# Processed: theme_1 = theme_环保, topic = topic_环境
# Processed: theme_1 = theme_节假日活动, topic = topic_文化
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育
# Processed: theme_1 = theme_科普知识与现代技术, topic = topic_科技
# Processed: theme_1 = theme_节假日活动, topic = topic_文化
# Processed: theme_1 = theme_学习, topic = topic_教育
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_人际交往, topic = topic_个人特征与生活
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与个人
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_饮食, topic = topic_饮食与餐饮
# Processed: theme_1 = theme_饮食, topic = topic_饮食与餐饮
# Processed: theme_1 = theme_人际交往, topic = topic_家庭
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_人际交往, topic = topic_人物与人际关系
# Processed: theme_1 = theme_天气, topic = topic_气候与环境
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_旅游与交通, topic = topic_生活服务
# Processed: theme_1 = theme_日常活动, topic = topic_社会活动
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与关系
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_家庭
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与关系
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与关系
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_旅游与交通, topic = topic_交通与时间管理
# Processed: theme_1 = theme_计划与安排, topic = topic_旅游与计划
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_人物描写, topic = topic_个人特征与生活
# Processed: theme_1 = theme_学校, topic = topic_教育与校园
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育
# Processed: theme_1 = theme_个人信息, topic = topic_节日与礼物
# Processed: theme_1 = theme_压力, topic = topic_学术
# Processed: theme_1 = theme_天气, topic = topic_气候与环境
# Processed: theme_1 = theme_饮食, topic = topic_饮食与健康
# Processed: theme_1 = theme_服装, topic = topic_商业
# Processed: theme_1 = theme_购物, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_家庭劳动, topic = topic_家庭
# Processed: theme_1 = theme_人际交往, topic = topic_社会活动
# Processed: theme_1 = theme_天气, topic = topic_自然与环境
# Processed: theme_1 = theme_自然, topic = topic_环境
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育
# Processed: theme_1 = theme_计划与安排, topic = topic_旅行与交通
# Processed: theme_1 = theme_节假日活动, topic = topic_文化与活动
# Processed: theme_1 = theme_地点, topic = topic_休闲与生活
# Processed: theme_1 = theme_人物描写, topic = topic_个人特征与生活
# Processed: theme_1 = theme_活动安排, topic = topic_社会活动
# Processed: theme_1 = theme_日常活动, topic = topic_教育与校园
# Processed: theme_1 = theme_购物, topic = topic_商业
# Processed: theme_1 = theme_文学与艺术, topic = topic_文化与活动
# Processed: theme_1 = theme_求助, topic = topic_社会
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_计划与安排, topic = topic_旅行
# Processed: theme_1 = theme_热点话题, topic = topic_环境
# Processed: theme_1 = theme_计划与安排, topic = topic_生活与设施
# Processed: theme_1 = theme_文娱与体育, topic = topic_文化与活动
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_社会活动
# Processed: theme_1 = theme_地点, topic = topic_旅行
# Processed: theme_1 = theme_娱乐, topic = topic_社会活动
# Processed: theme_1 = theme_服装, topic = topic_购物与时尚
# Processed: theme_1 = theme_购物, topic = topic_购物与时尚
# Processed: theme_1 = theme_娱乐, topic = topic_娱乐
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康与生活
# Processed: theme_1 = theme_地点, topic = topic_旅行
# Processed: theme_1 = theme_饮食, topic = topic_饮食与健康
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_计划与安排, topic = topic_健康与生活
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_娱乐
# Processed: theme_1 = theme_自我介绍, topic = topic_教育与背景
# Processed: theme_1 = theme_物品, topic = topic_物品与消费
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行
# Processed: theme_1 = theme_旅游与交通, topic = topic_出行与旅游
# Processed: theme_1 = theme_求助, topic = topic_社会
# Processed: theme_1 = theme_饮食, topic = topic_饮食与健康
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康与生活
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康与健身
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_日常活动, topic = topic_健康与生活
# Processed: theme_1 = theme_工作, topic = topic_教育
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_安全与救护, topic = topic_旅行
# Processed: theme_1 = theme_购物, topic = topic_饮食
# Processed: theme_1 = theme_通讯, topic = topic_人际交流
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康与生活
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_娱乐
# Processed: theme_1 = theme_个人信息, topic = topic_家庭
# Processed: theme_1 = theme_动物, topic = topic_娱乐
# Processed: theme_1 = theme_饮食, topic = topic_餐饮
# Processed: theme_1 = theme_节假日活动, topic = topic_文化
# Processed: theme_1 = theme_旅游与交通, topic = topic_教育与校园
# Processed: theme_1 = theme_地点, topic = topic_旅行
# Processed: theme_1 = theme_安全与救护, topic = topic_礼仪与交流
# Processed: theme_1 = theme_亲情, topic = topic_家庭与关系
# Processed: theme_1 = theme_工作, topic = topic_商业与创业
# Processed: theme_1 = theme_工作, topic = topic_商业与创业
# Processed: theme_1 = theme_工作, topic = topic_商业与创业
# Processed: theme_1 = theme_工作, topic = topic_商业与创业
# Processed: theme_1 = theme_工作, topic = topic_商业与创业
# Processed: theme_1 = theme_工作, topic = topic_商业与创业
# Processed: theme_1 = theme_工作, topic = topic_商业与创业
# Processed: theme_1 = theme_卫生与健康, topic = topic_个人特征与生活
# Processed: theme_1 = theme_科普知识与现代技术, topic = topic_科技与服务
# Processed: theme_1 = theme_自我介绍, topic = topic_教育与背景
# Processed: theme_1 = theme_服务, topic = topic_职业与工作
# Processed: theme_1 = theme_安全与救护, topic = topic_科技与服务
# Processed: theme_1 = theme_家庭劳动, topic = topic_家庭
# ...
# Processed: theme_1 = theme_卫生与健康, topic = topic_医疗与健康
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育与运动
# Processed: theme_1 = theme_居住情况, topic = topic_文化
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食与健康
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与个人
# Processed: theme_1 = theme_求助, topic = topic_物品与购物
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_教育及校园生活
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_饮食, topic = topic_饮食与健康
# Processed: theme_1 = theme_购物, topic = topic_家庭与生活
# Processed: theme_1 = theme_学校, topic = topic_教育与课堂
# Processed: theme_1 = theme_人物描写, topic = topic_家庭与个人
# Processed: theme_1 = theme_日常活动, topic = topic_情感表达与交流
# Processed: theme_1 = theme_日常活动, topic = topic_情感表达与交流
# Processed: theme_1 = theme_日常活动, topic = topic_情感表达与交流
# Processed: theme_1 = theme_日常活动, topic = topic_情感表达与交流
# Processed: theme_1 = theme_人际交往, topic = topic_文化与艺术
# Processed: theme_1 = theme_人际交往, topic = topic_文化与艺术
# Processed: theme_1 = theme_人际交往, topic = topic_文化与艺术
# Processed: theme_1 = theme_人际交往, topic = topic_文化与艺术
# Processed: theme_1 = theme_人际交往, topic = topic_文化与艺术
# Processed: theme_1 = theme_工作, topic = topic_职业与计划
# Processed: theme_1 = theme_个人信息, topic = topic_日常生活与社交
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_旅游与交通, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与关系
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与关系
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与关系
# Processed: theme_1 = theme_节假日活动, topic = topic_时间与活动安排
# Processed: theme_1 = theme_节假日活动, topic = topic_时间与活动安排
# Processed: theme_1 = theme_旅游与交通, topic = topic_生活方式
# Processed: theme_1 = theme_旅游与交通, topic = topic_生活方式
# Processed: theme_1 = theme_旅游与交通, topic = topic_生活方式
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育与运动
# Processed: theme_1 = theme_饮食, topic = topic_饮食与健康
# Processed: theme_1 = theme_旅游与交通, topic = topic_生活与设施
# Processed: theme_1 = theme_人际交往, topic = topic_教育与职业
# Processed: theme_1 = theme_物品, topic = topic_教育与职业
# Processed: theme_1 = theme_动物, topic = topic_旅行
# Processed: theme_1 = theme_动物, topic = topic_旅行
# Processed: theme_1 = theme_动物, topic = topic_旅行
# Processed: theme_1 = theme_动物, topic = topic_旅行
# Processed: theme_1 = theme_动物, topic = topic_旅行
# Processed: theme_1 = theme_动物, topic = topic_旅行
# Processed: theme_1 = theme_购物, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_购物, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_购物, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_购物, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_购物, topic = topic_购物与消费习惯
# Processed: theme_1 = theme_压力, topic = topic_教育与职业
# Processed: theme_1 = theme_人物描写, topic = topic_家庭与生活
# Processed: theme_1 = theme_节假日活动, topic = topic_节日与庆祝
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育
# Processed: theme_1 = theme_亲情, topic = topic_家庭与个人经历
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与休闲
# Processed: theme_1 = theme_饮食, topic = topic_餐饮与购物
# Processed: theme_1 = theme_饮食, topic = topic_饮食与餐饮
# Processed: theme_1 = theme_人际交往, topic = topic_文化
# Processed: theme_1 = theme_人际交往, topic = topic_文化
# Processed: theme_1 = theme_人际交往, topic = topic_文化
# Processed: theme_1 = theme_人际交往, topic = topic_家庭
# Processed: theme_1 = theme_人际交往, topic = topic_家庭
# Processed: theme_1 = theme_人际交往, topic = topic_家庭
# Processed: theme_1 = theme_动物, topic = topic_自然与环境
# Processed: theme_1 = theme_物品, topic = topic_物品与识别
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_旅行与休闲
# Processed: theme_1 = theme_时间, topic = topic_确认与安排
# Processed: theme_1 = theme_旅游与交通, topic = topic_娱乐与休闲
# Processed: theme_1 = theme_卫生与健康, topic = topic_健康与生活
# Processed: theme_1 = theme_科普知识与现代技术, topic = topic_科技
# Processed: theme_1 = theme_日常活动, topic = topic_教育与校园
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_家庭与安全
# Processed: theme_1 = theme_学校, topic = topic_生活方式
# Processed: theme_1 = theme_学校, topic = topic_生活方式
# Processed: theme_1 = theme_学校, topic = topic_生活方式
# Processed: theme_1 = theme_通讯, topic = topic_日常交流
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_天气, topic = topic_四季与活动
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_计划与安排, topic = topic_生活与设施
# Processed: theme_1 = theme_人际交往, topic = topic_生活方式
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_求助, topic = topic_物品与消费
# Processed: theme_1 = theme_饮食, topic = topic_饮食与烹饪
# Processed: theme_1 = theme_饮食, topic = topic_饮食与烹饪
# Processed: theme_1 = theme_人际交往, topic = topic_人物与人际关系
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与个人
# Processed: theme_1 = theme_服务, topic = topic_职业与工作
# Processed: theme_1 = theme_学校, topic = topic_个人发展
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_饮食
# Processed: theme_1 = theme_饮食, topic = topic_饮食
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_教育, topic = topic_教育与校园
# Processed: theme_1 = theme_饮食, topic = topic_饮食与文化
# Processed: theme_1 = theme_学校, topic = topic_教育与校园
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_个人信息, topic = topic_旅行
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_教育, topic = topic_教育与职业
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_文娱与体育, topic = topic_体育与运动
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_卫生与健康, topic = topic_运动与健康
# Processed: theme_1 = theme_服务, topic = topic_文化
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_节假日活动, topic = topic_文化与习俗
# Processed: theme_1 = theme_地点, topic = topic_社会与社区
# Processed: theme_1 = theme_旅游与交通, topic = topic_出行与旅游
# Processed: theme_1 = theme_情感与情绪, topic = topic_家庭与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_计划与安排, topic = topic_社会
# Processed: theme_1 = theme_天气, topic = topic_户外与自然
# Processed: theme_1 = theme_居住情况, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与个人
# Processed: theme_1 = theme_人际交往, topic = topic_人物与人际关系
# Processed: theme_1 = theme_日常活动, topic = topic_教育与校园
# Processed: theme_1 = theme_服务, topic = topic_社会与社区
# Processed: theme_1 = theme_服务, topic = topic_社会与社区
# Processed: theme_1 = theme_服务, topic = topic_社会与社区
# Processed: theme_1 = theme_服务, topic = topic_社会与社区
# Processed: theme_1 = theme_服务, topic = topic_社会与社区
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_计划与安排, topic = topic_生活方式
# Processed: theme_1 = theme_服务, topic = topic_教育与职业
# Processed: theme_1 = theme_文娱与体育, topic = topic_娱乐活动
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与社区
# Processed: theme_1 = theme_购物, topic = topic_商业
# Processed: theme_1 = theme_个人信息, topic = topic_家庭与生活
# Processed: theme_1 = theme_经历, topic = topic_旅行
# Processed: theme_1 = theme_学校, topic = topic_文化与教育
# Processed: theme_1 = theme_购物, topic = topic_消费行为
# Processed: theme_1 = theme_人际交往, topic = topic_家庭
# Processed: theme_1 = theme_节假日活动, topic = topic_文化
# Processed: theme_1 = theme_旅游与交通, topic = topic_场所与方向指引
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅游与出行
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与休闲
# Processed: theme_1 = theme_动物, topic = topic_自然与环境
# Processed: theme_1 = theme_学习, topic = topic_教育与学习
# Processed: theme_1 = theme_神话与传说, topic = topic_旅行
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_亲情, topic = topic_社会与社区
# Processed: theme_1 = theme_人际交往, topic = topic_家庭
# Processed: theme_1 = theme_历史与社会, topic = topic_饮食与文化
# Processed: theme_1 = theme_历史与社会, topic = topic_饮食与文化
# Processed: theme_1 = theme_旅游与交通, topic = topic_教育与校园
# Processed: theme_1 = theme_居住情况, topic = topic_家庭
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_邀请, topic = topic_娱乐与体育
# Processed: theme_1 = theme_卫生与健康, topic = topic_运动与健康
# Processed: theme_1 = theme_人物描写, topic = topic_个人特征与生活
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_物品, topic = topic_物品与消费
# Processed: theme_1 = theme_自我介绍, topic = topic_教育与背景
# Processed: theme_1 = theme_工作, topic = topic_职业与计划
# Processed: theme_1 = theme_工作, topic = topic_职业与计划
# Processed: theme_1 = theme_工作, topic = topic_职业与计划
# Processed: theme_1 = theme_工作, topic = topic_职业与计划
# Processed: theme_1 = theme_工作, topic = topic_职业与计划
# Processed: theme_1 = theme_计划与安排, topic = topic_时间与活动安排
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_人物描写, topic = topic_家庭与个人
# Processed: theme_1 = theme_购物, topic = topic_家庭与生活
# Processed: theme_1 = theme_卫生与健康, topic = topic_教育
# Processed: theme_1 = theme_天气, topic = topic_运动与健康
# Processed: theme_1 = theme_物品, topic = topic_酒店管理
# Processed: theme_1 = theme_娱乐, topic = topic_娱乐与休闲生活
# Processed: theme_1 = theme_娱乐, topic = topic_娱乐与休闲生活
# Processed: theme_1 = theme_娱乐, topic = topic_娱乐与休闲生活
# Processed: theme_1 = theme_娱乐, topic = topic_娱乐与休闲生活
# Processed: theme_1 = theme_娱乐, topic = topic_娱乐与休闲生活
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_出行与旅游
# Processed: theme_1 = theme_服务, topic = topic_饮食与烹饪
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_服装, topic = topic_个人特征与生活
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_居住情况, topic = topic_社交与个人事务
# Processed: theme_1 = theme_日常活动, topic = topic_情感表达与交流
# Processed: theme_1 = theme_日常活动, topic = topic_情感表达与交流
# Processed: theme_1 = theme_日常活动, topic = topic_情感表达与交流
# Processed: theme_1 = theme_日常活动, topic = topic_情感表达与交流
# Processed: theme_1 = theme_日常活动, topic = topic_情感表达与交流
# Processed: theme_1 = theme_日常活动, topic = topic_情感表达与交流
# Processed: theme_1 = theme_日常活动, topic = topic_情感表达与交流
# Processed: theme_1 = theme_服务, topic = topic_公共服务
# Processed: theme_1 = theme_周围的环境, topic = topic_生活与人物
# Processed: theme_1 = theme_周围的环境, topic = topic_生活与人物
# Processed: theme_1 = theme_周围的环境, topic = topic_生活与人物
# Processed: theme_1 = theme_周围的环境, topic = topic_生活与人物
# Processed: theme_1 = theme_周围的环境, topic = topic_生活与人物
# Processed: theme_1 = theme_节假日活动, topic = topic_文化
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_环保, topic = topic_社会与社区
# Processed: theme_1 = theme_人物描写, topic = topic_生活与人物
# Processed: theme_1 = theme_人物描写, topic = topic_生活与人物
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_购物, topic = topic_购物与交易
# Processed: theme_1 = theme_计划与安排, topic = topic_社会
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_计划与安排, topic = topic_生活与人物
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_教育, topic = topic_文化与教育
# Processed: theme_1 = theme_节假日活动, topic = topic_社交与活动
# Processed: theme_1 = theme_节假日活动, topic = topic_社交与活动
# Processed: theme_1 = theme_节假日活动, topic = topic_社交与活动
# Processed: theme_1 = theme_节假日活动, topic = topic_社交与活动
# Processed: theme_1 = theme_节假日活动, topic = topic_社交与活动
# Processed: theme_1 = theme_节假日活动, topic = topic_社交与活动
# Processed: theme_1 = theme_计划与安排, topic = topic_规划与计划
# Processed: theme_1 = theme_文学与艺术, topic = topic_文化与教育
# Processed: theme_1 = theme_学习, topic = topic_教育与校园
# Processed: theme_1 = theme_活动安排, topic = topic_日程与安排
# Processed: theme_1 = theme_计划与安排, topic = topic_旅游与计划
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食
# Processed: theme_1 = theme_卫生与健康, topic = topic_饮食
# Processed: theme_1 = theme_亲情, topic = topic_家庭与关系
# Processed: theme_1 = theme_工作, topic = topic_职业和生涯
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_旅游与交通, topic = topic_旅行与交通
# Processed: theme_1 = theme_计划与安排, topic = topic_旅行与交通
# Processed: theme_1 = theme_活动安排, topic = topic_健康与生活
# Processed: theme_1 = theme_学校, topic = topic_校园与学校
# Processed: theme_1 = theme_活动安排, topic = topic_文化与社交
# Processed: theme_1 = theme_学校, topic = topic_个人特征与生活
# Processed: theme_1 = theme_学校, topic = topic_个人特征与生活
# Processed: theme_1 = theme_地点, topic = topic_方位与位置
# Processed: theme_1 = theme_学校, topic = topic_教育与职业
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_休闲与娱乐
# Processed: theme_1 = theme_经历, topic = topic_出行与旅游
# Processed: theme_1 = theme_天气, topic = topic_自然与环境
# Processed: theme_1 = theme_工作, topic = topic_职业与工作
# Processed: theme_1 = theme_工作, topic = topic_职业与工作
# Processed: theme_1 = theme_人物描写, topic = topic_人物特征
# Processed: theme_1 = theme_活动安排, topic = topic_生活与人物
# Processed: theme_1 = theme_教育, topic = topic_经济交易
# Processed: theme_1 = theme_卫生与健康, topic = topic_运动与健康
# Processed: theme_1 = theme_旅游与交通, topic = topic_出行与旅游
# Processed: theme_1 = theme_自我介绍, topic = topic_教育与职业
# Processed: theme_1 = theme_自我介绍, topic = topic_教育与职业
# Processed: theme_1 = theme_自我介绍, topic = topic_教育与职业
# Processed: theme_1 = theme_自我介绍, topic = topic_教育与职业
# Processed: theme_1 = theme_自我介绍, topic = topic_教育与职业
# Processed: theme_1 = theme_服务, topic = topic_职业与工作
# Processed: theme_1 = theme_物品, topic = topic_社会交往与生活
# Processed: theme_1 = theme_计划与安排, topic = topic_生活与设施
# Processed: theme_1 = theme_友情, topic = topic_家庭与个人
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_计划与安排, topic = topic_时间与活动
# Processed: theme_1 = theme_动物, topic = topic_农业与自然
# Processed: theme_1 = theme_天气, topic = topic_运动与健康
# Processed: theme_1 = theme_个人信息, topic = topic_生活与人物
# Processed: theme_1 = theme_历史与社会, topic = topic_社会与社区
# Processed: theme_1 = theme_兴趣与爱好, topic = topic_家庭与个人
# Processed: theme_1 = theme_人际交往, topic = topic_家庭
# Processed: theme_1 = theme_活动安排, topic = topic_社交与活动
# Processed: theme_1 = theme_计划与安排, topic = topic_旅行与交通
# Processed: theme_1 = theme_日常活动, topic = topic_家庭与个人
# Processed: theme_1 = theme_节假日活动, topic = topic_社会与社区
# Processed: theme_1 = theme_家庭、朋友与周围的人, topic = topic_家庭与安全
# Processed: theme_1 = theme_学习, topic = topic_教育与职业
# Processed: theme_1 = theme_卫生与健康, topic = topic_运动与健康
# Processed: theme_1 = theme_友情, topic = topic_职场与沟通
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_学校, topic = topic_教育与阅读
# Processed: theme_1 = theme_地点, topic = topic_社交与活动
# Processed: theme_1 = theme_地点, topic = topic_社交与活动
# Processed: theme_1 = theme_文学与艺术, topic = topic_艺术与鉴赏
# Processed: theme_1 = theme_日常活动, topic = topic_个人特征与生活
# Processed: theme_1 = theme_购物, topic = topic_购物
# Processed: theme_1 = theme_购物, topic = topic_购物
# Processed: theme_1 = theme_购物, topic = topic_购物
# cora.cites 和 cora.content 文件已保存。
# /tmp/ipykernel_3104290/61889573.py:48: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   adj_matrix = nx.adjacency_matrix(G, nodelist=nodes).todense()

# %% [markdown]
# ### 调用

# %%
import torch
import numpy as np
import os
import random
import pandas as pd
import scipy.sparse as sp
from torch_geometric.data import Data
from sklearn.preprocessing import LabelEncoder
from node2vec import Node2Vec
import networkx as nx
import matplotlib
matplotlib.use('Agg')

def seed_everything(seed=2023):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

seed_everything()

def load_cora_data(data_path='/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data'):
    content_df = pd.read_csv(os.path.join(data_path, "cora.content"), delimiter="\t", header=None)
    content_df.set_index(0, inplace=True)
    index = content_df.index.tolist()

    features = np.array([list(map(float, row[0].split())) for row in content_df.iloc[:, :-1].values])
    features = sp.csr_matrix(features, dtype=np.float32)

    labels = content_df.values[:, -1]
    class_encoder = LabelEncoder()
    labels = class_encoder.fit_transform(labels)

    cites_df = pd.read_csv(os.path.join(data_path, "cora.cites"), delimiter="\t", header=None)
    cites_df[0] = cites_df[0].astype(str)
    cites_df[1] = cites_df[1].astype(str)
    cites = [tuple(x) for x in cites_df.values]
    edges = [(index.index(cite[0]), index.index(cite[1])) for cite in cites]
    edges = np.array(edges).T

    data = Data(x=torch.from_numpy(np.array(features.todense())),
                edge_index=torch.LongTensor(edges),
                y=torch.from_numpy(labels))

    idx_train = range(400)
    idx_val = range(400, 500)
    idx_test = range(500, 561)

    def index_to_mask(index, size):
        mask = np.zeros(size, dtype=bool)
        mask[index] = True
        return mask

    data.train_mask = index_to_mask(idx_train, size=labels.shape[0])
    data.val_mask = index_to_mask(idx_val, size=labels.shape[0])
    data.test_mask = index_to_mask(idx_test, size=labels.shape[0])

    def to_networkx(data):
        edge_index = data.edge_index.to(torch.device('cpu')).numpy()
        G = nx.DiGraph()
        for src, tar in edge_index.T:
            G.add_edge(src, tar)
        return G

    networkx_data = to_networkx(data)

    return data, networkx_data

pyg_data, networkx_data = load_cora_data()


def Node2Vec_run(networkx_data, dimensions=64, walk_length=30, num_walks=200, model_save_path="node2vec2.model"):
    node2vec = Node2Vec(networkx_data, dimensions=dimensions, walk_length=walk_length, num_walks=num_walks, workers=4)
    model = node2vec.fit(window=10, min_count=1, batch_words=4)
    nodes = model.wv.index_to_key
    embeddings = model.wv[nodes]
    
    # 保存模型
    model.save(model_save_path)
    
    return model, nodes, embeddings
_, _, node2vec_embeddings = Node2Vec_run(networkx_data, num_walks=200, model_save_path="/mnt/new_pfs/liming_team/auroraX/chenlong/Graph-Networks/topic_data/node2vec2.model")
print("node2vec_embeddings:", np.array(node2vec_embeddings).shape)
